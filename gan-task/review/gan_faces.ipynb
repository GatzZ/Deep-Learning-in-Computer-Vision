# %%
from __future__ import division
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from glob import glob
import time
import os

from ops import *
from utils import *
# Out:
# /Library/anaconda/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# %matplotlib inline

# %% [markdown]
# Today we are going to train GAN for generating faces and then we will make fun playing with it. Generative adversarial networks (GANs) are deep neural net architectures comprised of two nets, pitting one against the other (thus the “adversarial”). One neural network, called the generator, generates new faces, while the other, the discriminator,  decides whether each instance of face it reviews belongs to the actual training dataset or not.
#
# Firstly download aligned faces of celebrities from here <a href="https://yadi.sk/d/xjuClJJH3MAVXh">link</a> and extract them into folder near ipython notebook.

# %% [markdown]
# # Implementation of GAN

# %% [markdown]
# Constant variables below depends on your dataset and choosing of architecture.

# %%
DATA_PATH = '/Users/nikitakaraev/Desktop/Computer_visionHES-coursera/GAN/aligned/raw_images' # Path to the dataset with celebA faces
Z_DIM=100 # Dimension of face's manifold
GENERATOR_DENSE_SIZE=64*8 # Length of first tensor in generator

IMAGE_SIZE=64 # Shapes of input image
BATCH_SIZE=64 # Batch size
N_CHANNELS = 3 # Number channels of input image

MERGE_X = 8 # Number images in merged image
MERGE_Y =  BATCH_SIZE//MERGE_X

# %%
assert(os.path.exists(DATA_PATH)), 'Please, download aligned celebA to DATA_PATH folder'

# %% [markdown]
# Let's define GAN. To do it, we need to define generator, discriminator and loss functions.

# %% [markdown]
# Here are some tips on the architecture of the generator:
# 1. The deeper is convolution, the less filters is using.
# 2. Apply deconvolutions-relu layers to achieve input image shape.
# 3. Use batch normalization before nonlinearity for speed and stability of learning.
# 4. Use tanh activation at the end of network (in this case images should be scaled to [-1, 1])
# 5. To force generator not to collapse and produce different outputs initialize bias with zero (see linear layer).
#
# Other useful tips: https://github.com/soumith/ganhacks. Example of architecture see below. You may also use defined layers from ops.py. <b> Please, use names for layers started with "g\_" for generator and "d_" for discriminator.</b>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/carpedm20/DCGAN-tensorflow/master/DCGAN.png">

# %% [markdown]
# ## Writing generator function (1 point)

# %%
def generator(z, is_training):
    # Firstly let's reshape input vector into 3-d tensor. 
    with tf.variable_scope("gen", reuse=tf.AUTO_REUSE):
        z_ = linear(z, GENERATOR_DENSE_SIZE * 4 * 4, 'g_h0_lin')
        h_in = tf.reshape(z_, [-1, 4, 4, GENERATOR_DENSE_SIZE])
    
        h_1 = deconv2d(h_in, [BATCH_SIZE, 8, 8, int(GENERATOR_DENSE_SIZE/2.0)], name='g_deconv2d_1')
        h_1 = batch_norm(name="g_batch_norm_1")(h_1, train=is_training)
        h_1 = lrelu(h_1, name="g_lrelu_1")
        h_2 = deconv2d(h_1, [BATCH_SIZE, 16, 16, int(GENERATOR_DENSE_SIZE/4.0)], name='g_deconv2d_2')
        h_2 = batch_norm(name="g_batch_norm_2")(h_2, train=is_training)
        h_2 = lrelu(h_2, name="g_lrelu_2")
        h_3 = deconv2d(h_2, [BATCH_SIZE, 32, 32, int(GENERATOR_DENSE_SIZE/8.0)], name='g_deconv2d_3')
        h_3 = batch_norm(name="g_batch_norm_3")(h_3, train=is_training)
        h_3 = lrelu(h_3, name="g_lrelu_3")
    
        h_out = deconv2d(h_3, [BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, N_CHANNELS],
            name='g_out')

    return tf.nn.tanh(h_out)

# %% [markdown]
# Now let's define discriminator. Discriminator takes 3d tensor as input and outputs one number - probability that this is an image.
#
# Some advice for discriminator's architecture:
# 1. Use batch normalization between convolutions and nonlinearities.
# 2. Use leaky relu with the leak about 0.2.
# 3. The deeper the layer, the more filters you can use.
#
# If you use batch normalization, please define every layer in their own scope and pass is_training parameter there. Or you may use class of batch normalization from ops.py. Do not forget to fratten tensor after the convolution blocks.

# %% [markdown]
# ## Writing discriminator function (1 point)

# %%
def discriminator(image, is_training, batch_norms=None):
    with tf.variable_scope("disc", reuse=tf.AUTO_REUSE):
        c_1 = conv2d(image, 16, k_h=5, k_w=5, d_h=2, d_w=2, name="d_conv2d_1")
        c_1 = batch_norm(name="d_batch_norm_1")(c_1, train=is_training)
        c_1 = lrelu(c_1, name="d_lrelu_1")
        c_2 = conv2d(c_1, 64, k_h=5, k_w=5, d_h=2, d_w=2, name="d_conv2d_2")
        c_2 = batch_norm(name="d_batch_norm_2")(c_2, train=is_training)
        c_2 = lrelu(c_2, name="d_lrelu_2")
        c_3 = conv2d(c_2, 256, k_h=5, k_w=5, d_h=2, d_w=2, name="d_conv2d_3")
        c_3 = batch_norm(name="d_batch_norm_3")(c_3, train=is_training)
        c_3 = lrelu(c_3, name="d_lrelu_3")
        c_4 = conv2d(c_3, 512, k_h=3, k_w=3, d_h=2, d_w=2, name="d_conv2d_4")
        c_4 = batch_norm(name="d_batch_norm_4")(c_4, train=is_training)
        c_4 = lrelu(c_4, name="d_lrelu_4")
        linear_out = conv2d(c_4, 1, k_h=4, k_w=4, d_h=1, d_w=1, name="d_conv2d_5", padding='VALID')
    
    return tf.nn.sigmoid(linear_out), linear_out

# %% [markdown]
# Now let's define generator and discriminator.

# %%
tf.reset_default_graph()
is_training = tf.placeholder(tf.bool, name='is_training')

with tf.variable_scope("G") as scope:
    z = tf.placeholder(tf.float32, [None, Z_DIM], name='z')
    G = generator(z, is_training)

with tf.variable_scope('D') as scope:
    images = tf.placeholder(tf.float32, shape=[None, IMAGE_SIZE, IMAGE_SIZE, N_CHANNELS])
    batch_norms = [batch_norm(name='d_batch_norm_1'),batch_norm(name='d_batch_norm_2'),batch_norm(name='d_batch_norm_3'),batch_norm(name='d_batch_norm_4')]
    # If you use batch norms from ops define them here (like batch_norms = [batch_norm(name='d_bn0')])
    # and pass to discriminator function instances.
    D_real, D_real_logits = discriminator(images, is_training, batch_norms)
    scope.reuse_variables()
    D_fake, D_fake_logits = discriminator(G, is_training, batch_norms)

# %% [markdown]
# Write definition of loss funstions according to formulas:
# $$ D\_loss = \frac{-1}{m} \sum_{i=1}^{m}[\log{D(x_i)} + \log{(1 - D(G(z_i)))}]$$
# $$ G\_loss = \frac{1}{m} \sum_{i=1}^{m} \log{(1 - D(G(z_i)))}$$
#
# Or for better learning you may try other loss for generator:
# $$ G\_loss = \frac{-1}{m} \sum_{i=1}^{m} \log{(D(G(z_i)))}$$

# %% [markdown]
# ## Writing loss functions (2 points)

# %%
"""
        You code goes here. Define discriminator and generator losses
"""
#Z = tf.placeholder(tf.float32, shape=[BATCH_SIZE, Z_DIM])
#g_sample = generator(z, True)
#images = tf.placeholder(tf.float32, shape=[BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, 3])
#disc_r = discriminator(images, True)[0]
#disc_f = discriminator(g_sample, True)[0]


d_loss_real = -tf.reduce_mean(tf.log(D_real))
    
d_loss_fake = -tf.reduce_mean(tf.log(tf.ones_like(D_fake)-D_fake))

d_loss = d_loss_real + d_loss_fake

g_loss = -tf.reduce_mean(tf.log(D_fake))

# %%
g_loss.get_shape()
# Out:
# TensorShape([])

# %% [markdown]
# Create optimizers. We use different optimizers for discriminator and generator, so we needed a separate prefix for the discriminator and generator variables (g_ for generator, d_ for disciminator).

# %%
tvars = tf.trainable_variables()
## All variables of discriminator
d_vars = [v for v in tvars if 'd_' in v.name]

## All variables of generator
g_vars = [v for v in tvars if 'g_' in v.name]

LEARNING_RATE = 0.0002 # Learning rate for adam optimizer
BETA = 0.5 # Beta paramater in adam optimizer

##Optimizers - ypu may use your favourite instead.
d_optim = tf.train.AdamOptimizer(LEARNING_RATE, beta1=BETA) \
                  .minimize(d_loss, var_list=d_vars)
g_optim = tf.train.AdamOptimizer(LEARNING_RATE, beta1=BETA) \
                  .minimize(g_loss, var_list=g_vars)

# %% [markdown]
# Load data:

# %%
data = glob(os.path.join(DATA_PATH, "*.png"))
assert(len(data) > 0), "Length of training data should be more than zero"

# %% [markdown]
# Functions for training and evaluations.

# %%
def load(sess, load_dir):
    """load network's paramaters
    
    load_dir : path to load dir
    """
    saver = tf.train.Saver()
    ckpt = tf.train.get_checkpoint_state(load_dir)
    if ckpt and ckpt.model_checkpoint_path:
            saver.restore(sess, ckpt.model_checkpoint_path)

# %% [markdown]
# ## Training GAN (1 point + 2 for good results)

# %%
def train(sess, load_dir=None, save_frequency=100, sample_frequency=100, sample_dir='sample_faces',
          save_dir='checkpoint', max_to_keep=1, model_name='dcgan.model',
          n_epochs=25, n_generator_update=2):
    """train gan
    Parameters
    -------------------------------------------
    load_dir : str, default = None
        path to the folder with parameters
    save_frequency: int, default = 100
        how often save parameters []
    sample_frequency: int, default = None (not sample)
        how often sample faces
    sample_dir: str, default = samples
        directory for sampled images
    save_dir: str, default = 'checkpoint'
        path where to save parameters
    max_to_keep: int, default = 1
        how many last checkpoints to store
    model_name: str, default='dcgan.model'
        name of model
    n_epochs: int, default = 25 
        number epochs to train
    n_generator_update: int, default = 2
        how many times run generator updates per one discriminator update
    -------------------------------------------
    """
    
    if save_frequency is not None:
        saver = tf.train.Saver(max_to_keep=max_to_keep)
        
    if load_dir is not None:
        print("Reading checkpoints...")
        load(sess, load_dir)
        print("Loaded checkpoints")
    else:
        try:
            tf.global_variables_initializer().run()
        except:
            tf.initialize_all_variables().run()

    counter=1
    start_time = time.time()
    
    for epoch in xrange(n_epochs):
        batch_idxs = min(len(data), np.inf) // BATCH_SIZE
        for idx in xrange(0, batch_idxs):
                batch_files = data[idx*BATCH_SIZE:(idx+1)*BATCH_SIZE]
                batch = [get_image(batch_file, IMAGE_SIZE) for batch_file in batch_files]
                batch_images = np.array(batch).astype(np.float32)
                batch_z = np.random.uniform(-1, 1, [BATCH_SIZE, Z_DIM]).astype(np.float32)

                # Update D network
                sess.run(d_optim, feed_dict={images: batch_images, z: batch_z, is_training: True})

                # Update G network
                for _ in range(n_generator_update):
                    sess.run(g_optim,
                        feed_dict={z: batch_z, is_training: True})

                errD_fake = d_loss_fake.eval({z: batch_z, is_training: False})
                errD_real = d_loss_real.eval({images: batch_images, is_training: False})
                errG = g_loss.eval({z: batch_z, is_training: False})

                
                print("Epoch: [{:2d}] [{:4d}/{:4d}] time: {:4.4f}, d_loss: {}, g_loss: {}".format(
                    epoch, idx, batch_idxs, float(time.time() - start_time), 
                    errD_fake+errD_real, errG))

                if np.mod(counter, save_frequency) == 1:
                    print("Saved model")
                    saver.save(sess, 
                               os.path.join(save_dir, model_name))

                if np.mod(counter, sample_frequency) == 1:
                    samples = sess.run(G, feed_dict={z: batch_z, is_training: False})
                    res = save_images(samples, [MERGE_X, MERGE_Y],
                                os.path.join('/Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/', 'train_{:02d}_{:04d}.png'.format(epoch, idx)))
                    print("Sample saved: "+ str(res))
                    
                counter += 1

# %%
with tf.Session() as sess:
    train(sess, load_dir='/Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/checkpoint', save_dir='checkpoint')
# Out:
# Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/checkpoint/dcgan.model
# Loaded checkpoints
# Epoch: [ 0] [   0/2614] time: 19.3251, d_loss: 1.14754199982, g_loss: 0.934716105461
# Saved model
# Sample saved: True
# Epoch: [ 0] [   1/2614] time: 34.9834, d_loss: 1.24697184563, g_loss: 0.56015175581
# Epoch: [ 0] [   2/2614] time: 47.7175, d_loss: 1.29865336418, g_loss: 1.16023111343
# Epoch: [ 0] [   3/2614] time: 62.3423, d_loss: 1.32705616951, g_loss: 1.16598534584
# Epoch: [ 0] [   4/2614] time: 80.1998, d_loss: 1.28874886036, g_loss: 0.681129932404
# Epoch: [ 0] [   5/2614] time: 96.6973, d_loss: 1.26425766945, g_loss: 0.937839865685
# Epoch: [ 0] [   6/2614] time: 111.4809, d_loss: 1.24044466019, g_loss: 1.09594786167
# Epoch: [ 0] [   7/2614] time: 125.5619, d_loss: 1.16311895847, g_loss: 0.899212002754
# Epoch: [ 0] [   8/2614] time: 139.9284, d_loss: 1.27113306522, g_loss: 1.18410480022
# Epoch: [ 0] [   9/2614] time: 153.7654, d_loss: 1.26317048073, g_loss: 0.603284239769
# Epoch: [ 0] [  10/2614] time: 168.4016, d_loss: 1.25288295746, g_loss: 0.88418841362
# Epoch: [ 0] [  11/2614] time: 182.3424, d_loss: 1.31007933617, g_loss: 0.818151056767
# Epoch: [ 0] [  12/2614] time: 196.8638, d_loss: 1.31439375877, g_loss: 0.589897155762
# Epoch: [ 0] [  13/2614] time: 211.4490, d_loss: 1.19486474991, g_loss: 0.803726553917
# Epoch: [ 0] [  14/2614] time: 225.8163, d_loss: 1.27407705784, g_loss: 1.09824585915
# Epoch: [ 0] [  15/2614] time: 240.7179, d_loss: 1.25080084801, g_loss: 0.611386060715
# Epoch: [ 0] [  16/2614] time: 254.9757, d_loss: 1.27939653397, g_loss: 0.983112096786
# Epoch: [ 0] [  17/2614] time: 269.1916, d_loss: 1.43927598, g_loss: 0.97583591938
# Epoch: [ 0] [  18/2614] time: 283.6535, d_loss: 1.37756764889, g_loss: 0.505089879036
# Epoch: [ 0] [  19/2614] time: 298.1898, d_loss: 1.63429260254, g_loss: 1.5287528038
# Epoch: [ 0] [  20/2614] time: 313.1178, d_loss: 1.40039288998, g_loss: 0.379317522049
# Epoch: [ 0] [  21/2614] time: 327.3841, d_loss: 1.21756410599, g_loss: 1.0923551321
# Epoch: [ 0] [  22/2614] time: 342.1471, d_loss: 1.30318033695, g_loss: 0.991402029991
# Epoch: [ 0] [  23/2614] time: 357.5446, d_loss: 1.18653082848, g_loss: 0.704231739044
# Epoch: [ 0] [  24/2614] time: 371.4249, d_loss: 1.22254288197, g_loss: 0.825629353523
# Epoch: [ 0] [  25/2614] time: 385.0647, d_loss: 1.43278491497, g_loss: 0.886565804482
# Epoch: [ 0] [  26/2614] time: 399.3365, d_loss: 1.2892677784, g_loss: 0.795071721077
# Epoch: [ 0] [  27/2614] time: 412.9150, d_loss: 1.21186113358, g_loss: 0.710225343704
# Epoch: [ 0] [  28/2614] time: 426.1822, d_loss: 1.30387961864, g_loss: 1.21705341339
# Epoch: [ 0] [  29/2614] time: 441.8848, d_loss: 1.33509683609, g_loss: 0.487549483776
# Epoch: [ 0] [  30/2614] time: 456.6885, d_loss: 1.39429628849, g_loss: 1.51221871376
# Epoch: [ 0] [  31/2614] time: 470.3302, d_loss: 1.24302387238, g_loss: 0.904551744461
# Epoch: [ 0] [  32/2614] time: 484.2701, d_loss: 1.10879981518, g_loss: 0.875815868378
# Epoch: [ 0] [  33/2614] time: 500.3469, d_loss: 1.26367127895, g_loss: 1.0508878231
# Epoch: [ 0] [  34/2614] time: 514.5387, d_loss: 1.36654543877, g_loss: 0.743045330048
# Epoch: [ 0] [  35/2614] time: 527.7590, d_loss: 1.04911601543, g_loss: 0.977575242519
# Epoch: [ 0] [  36/2614] time: 541.1403, d_loss: 1.37264442444, g_loss: 0.527294099331
# Epoch: [ 0] [  37/2614] time: 554.2963, d_loss: 1.11544060707, g_loss: 0.789167165756
# Epoch: [ 0] [  38/2614] time: 567.3220, d_loss: 1.12027096748, g_loss: 0.736777544022
# Epoch: [ 0] [  39/2614] time: 580.5515, d_loss: 1.35066962242, g_loss: 1.3654088974
# Epoch: [ 0] [  40/2614] time: 593.9046, d_loss: 1.23906707764, g_loss: 0.642391324043
# Epoch: [ 0] [  41/2614] time: 606.9686, d_loss: 1.26930129528, g_loss: 0.85592263937
# Epoch: [ 0] [  42/2614] time: 620.1134, d_loss: 1.31024110317, g_loss: 0.914289236069
# Epoch: [ 0] [  43/2614] time: 633.1988, d_loss: 1.34916007519, g_loss: 0.884715795517
# Epoch: [ 0] [  44/2614] time: 648.1282, d_loss: 1.35086011887, g_loss: 0.921141147614
# Epoch: [ 0] [  45/2614] time: 662.5220, d_loss: 1.27675414085, g_loss: 0.789047718048
# Epoch: [ 0] [  46/2614] time: 677.8797, d_loss: 1.13276994228, g_loss: 0.816478252411
# Epoch: [ 0] [  47/2614] time: 693.2210, d_loss: 1.31449651718, g_loss: 1.10318875313
# Epoch: [ 0] [  48/2614] time: 708.5081, d_loss: 1.25914239883, g_loss: 0.613908171654
# Epoch: [ 0] [  49/2614] time: 723.5904, d_loss: 1.14137864113, g_loss: 0.999327898026
# Epoch: [ 0] [  50/2614] time: 736.9810, d_loss: 1.16679191589, g_loss: 0.757547259331
# Epoch: [ 0] [  51/2614] time: 750.3371, d_loss: 1.10883510113, g_loss: 0.745991587639
# Epoch: [ 0] [  52/2614] time: 763.4607, d_loss: 1.23603510857, g_loss: 0.621608734131
# Epoch: [ 0] [  53/2614] time: 776.3914, d_loss: 1.36004376411, g_loss: 0.90929800272
# Epoch: [ 0] [  54/2614] time: 789.5050, d_loss: 1.12828266621, g_loss: 0.85398876667
# Epoch: [ 0] [  55/2614] time: 802.8925, d_loss: 1.16979026794, g_loss: 0.964199900627
# Epoch: [ 0] [  56/2614] time: 815.8839, d_loss: 1.31208515167, g_loss: 0.559572696686
# Epoch: [ 0] [  57/2614] time: 828.4243, d_loss: 1.202896595, g_loss: 1.09179246426
# Epoch: [ 0] [  58/2614] time: 840.8583, d_loss: 1.25231790543, g_loss: 0.693376600742
# Epoch: [ 0] [  59/2614] time: 853.3880, d_loss: 1.17487716675, g_loss: 1.05291032791
# Epoch: [ 0] [  60/2614] time: 865.8206, d_loss: 1.33110797405, g_loss: 1.10462665558
# Epoch: [ 0] [  61/2614] time: 878.3011, d_loss: 1.28074336052, g_loss: 0.820933759212
# Epoch: [ 0] [  62/2614] time: 890.9015, d_loss: 1.19992423058, g_loss: 0.667719721794
# Epoch: [ 0] [  63/2614] time: 903.3261, d_loss: 1.41277933121, g_loss: 1.40161573887
# Epoch: [ 0] [  64/2614] time: 915.8401, d_loss: 1.22097039223, g_loss: 0.637734115124
# Epoch: [ 0] [  65/2614] time: 928.3176, d_loss: 1.72909998894, g_loss: 1.94328320026
# Epoch: [ 0] [  66/2614] time: 940.7251, d_loss: 1.42506194115, g_loss: 0.407392978668
# Epoch: [ 0] [  67/2614] time: 953.6236, d_loss: 1.29572844505, g_loss: 0.681479811668
# Epoch: [ 0] [  68/2614] time: 966.1431, d_loss: 1.24474394321, g_loss: 1.15403831005
# Epoch: [ 0] [  69/2614] time: 978.2708, d_loss: 1.30771434307, g_loss: 0.521252989769
# Epoch: [ 0] [  70/2614] time: 990.9569, d_loss: 1.2184689045, g_loss: 1.29994535446
# Epoch: [ 0] [  71/2614] time: 1003.5324, d_loss: 1.23089420795, g_loss: 1.05614471436
# Epoch: [ 0] [  72/2614] time: 1016.1362, d_loss: 1.27903747559, g_loss: 0.631652712822
# Epoch: [ 0] [  73/2614] time: 1028.7266, d_loss: 1.1927921772, g_loss: 0.940470218658
# Epoch: [ 0] [  74/2614] time: 1041.4486, d_loss: 1.26978158951, g_loss: 0.858757376671
# Epoch: [ 0] [  75/2614] time: 1054.1350, d_loss: 1.36811208725, g_loss: 0.464208841324
# Epoch: [ 0] [  76/2614] time: 1067.1721, d_loss: 1.24595355988, g_loss: 1.06418633461
# Epoch: [ 0] [  77/2614] time: 1080.2062, d_loss: 1.4503878355, g_loss: 0.409117698669
# Epoch: [ 0] [  78/2614] time: 1093.4568, d_loss: 1.26020109653, g_loss: 1.24184632301
# Epoch: [ 0] [  79/2614] time: 1106.2048, d_loss: 1.34131813049, g_loss: 0.566719353199
# Epoch: [ 0] [  80/2614] time: 1118.9204, d_loss: 1.2341991663, g_loss: 0.886758565903
# Epoch: [ 0] [  81/2614] time: 1131.5852, d_loss: 1.2983366251, g_loss: 1.00237929821
# Epoch: [ 0] [  82/2614] time: 1144.3255, d_loss: 1.29941534996, g_loss: 0.565001308918
# Epoch: [ 0] [  83/2614] time: 1157.1374, d_loss: 1.78414201736, g_loss: 2.14434719086
# Epoch: [ 0] [  84/2614] time: 1169.9127, d_loss: 1.2610783577, g_loss: 0.721449613571
# Epoch: [ 0] [  85/2614] time: 1182.8750, d_loss: 1.92890250683, g_loss: 2.53874349594
# Epoch: [ 0] [  86/2614] time: 1196.1081, d_loss: 1.46065700054, g_loss: 0.430027127266
# Epoch: [ 0] [  87/2614] time: 1209.0445, d_loss: 1.1821398735, g_loss: 0.91292488575
# Epoch: [ 0] [  88/2614] time: 1222.0173, d_loss: 1.27899885178, g_loss: 0.723541617393
# Epoch: [ 0] [  89/2614] time: 1235.0136, d_loss: 1.36822533607, g_loss: 0.505319297314
# Epoch: [ 0] [  90/2614] time: 1248.2198, d_loss: 1.27010369301, g_loss: 1.18602561951
# Epoch: [ 0] [  91/2614] time: 1261.7041, d_loss: 1.39314329624, g_loss: 0.476587414742
# Epoch: [ 0] [  92/2614] time: 1275.4934, d_loss: 1.21771776676, g_loss: 0.897793471813
# Epoch: [ 0] [  93/2614] time: 1289.4363, d_loss: 1.17997074127, g_loss: 0.88317579031
# Epoch: [ 0] [  94/2614] time: 1302.8784, d_loss: 1.26901304722, g_loss: 0.619701743126
# Epoch: [ 0] [  95/2614] time: 1316.8135, d_loss: 1.22216176987, g_loss: 0.916875958443
# Epoch: [ 0] [  96/2614] time: 1329.9473, d_loss: 1.30957174301, g_loss: 0.662501692772
# Epoch: [ 0] [  97/2614] time: 1343.1382, d_loss: 1.32105100155, g_loss: 0.648208379745
# Epoch: [ 0] [  98/2614] time: 1356.4906, d_loss: 1.17146289349, g_loss: 0.767322182655
# Epoch: [ 0] [  99/2614] time: 1370.1403, d_loss: 1.12418031693, g_loss: 0.873601734638
# Epoch: [ 0] [ 100/2614] time: 1384.1640, d_loss: 1.24820947647, g_loss: 0.583625435829
# Saved model
# Sample saved: True
# Epoch: [ 0] [ 101/2614] time: 1402.4919, d_loss: 1.27744793892, g_loss: 0.981163263321
# Epoch: [ 0] [ 102/2614] time: 1417.0544, d_loss: 1.29974269867, g_loss: 0.79198551178
# Epoch: [ 0] [ 103/2614] time: 1431.2067, d_loss: 1.25403189659, g_loss: 1.12080693245
# Epoch: [ 0] [ 104/2614] time: 1444.4903, d_loss: 1.23852860928, g_loss: 0.871070027351
# Epoch: [ 0] [ 105/2614] time: 1457.5179, d_loss: 1.13535785675, g_loss: 0.78681409359
# Epoch: [ 0] [ 106/2614] time: 1471.5282, d_loss: 1.18655383587, g_loss: 0.874412596226
# Epoch: [ 0] [ 107/2614] time: 1485.8514, d_loss: 1.22068095207, g_loss: 1.11014616489
# Epoch: [ 0] [ 108/2614] time: 1500.1894, d_loss: 1.25614142418, g_loss: 0.663843750954
# Epoch: [ 0] [ 109/2614] time: 1514.3956, d_loss: 1.08817362785, g_loss: 0.979833483696
# Epoch: [ 0] [ 110/2614] time: 1528.6164, d_loss: 1.21087551117, g_loss: 0.767788529396
# Epoch: [ 0] [ 111/2614] time: 1542.9816, d_loss: 1.13336730003, g_loss: 0.807408094406
# Epoch: [ 0] [ 112/2614] time: 1557.4977, d_loss: 1.18796300888, g_loss: 0.872448682785
# Epoch: [ 0] [ 113/2614] time: 1572.1397, d_loss: 1.14657592773, g_loss: 0.732836484909
# Epoch: [ 0] [ 114/2614] time: 1586.4618, d_loss: 1.22727823257, g_loss: 0.701588869095
# Epoch: [ 0] [ 115/2614] time: 1601.2334, d_loss: 1.19950079918, g_loss: 0.690651416779
# Epoch: [ 0] [ 116/2614] time: 1615.4930, d_loss: 1.19883477688, g_loss: 0.81192868948
# Epoch: [ 0] [ 117/2614] time: 1629.9255, d_loss: 1.31150054932, g_loss: 0.581454396248
# Epoch: [ 0] [ 118/2614] time: 1645.4211, d_loss: 1.26182949543, g_loss: 0.810260653496
# Epoch: [ 0] [ 119/2614] time: 1662.1580, d_loss: 1.13059067726, g_loss: 0.772253155708
# Epoch: [ 0] [ 120/2614] time: 1677.6462, d_loss: 1.30632317066, g_loss: 1.24540758133
# Epoch: [ 0] [ 121/2614] time: 1692.9507, d_loss: 1.25059485435, g_loss: 0.617472469807
# Epoch: [ 0] [ 122/2614] time: 1708.3358, d_loss: 1.4869171381, g_loss: 1.28094851971
# Epoch: [ 0] [ 123/2614] time: 1723.2322, d_loss: 1.17966532707, g_loss: 0.63716673851
# Epoch: [ 0] [ 124/2614] time: 1736.7476, d_loss: 1.23556947708, g_loss: 1.20849144459
# Epoch: [ 0] [ 125/2614] time: 1750.3051, d_loss: 1.25409626961, g_loss: 0.751950860023
# Epoch: [ 0] [ 126/2614] time: 1766.5198, d_loss: 1.25574922562, g_loss: 0.944385528564
# Epoch: [ 0] [ 127/2614] time: 1781.8243, d_loss: 1.27396345139, g_loss: 0.918204247952
# Epoch: [ 0] [ 128/2614] time: 1797.6892, d_loss: 1.39548540115, g_loss: 0.481135487556
# Epoch: [ 0] [ 129/2614] time: 1815.6892, d_loss: 1.22860908508, g_loss: 1.16676545143
# Epoch: [ 0] [ 130/2614] time: 1829.5488, d_loss: 1.3252260685, g_loss: 0.514159858227
# Epoch: [ 0] [ 131/2614] time: 1843.0189, d_loss: 1.33028912544, g_loss: 1.27243161201
# Epoch: [ 0] [ 132/2614] time: 1856.4860, d_loss: 1.25816118717, g_loss: 0.68364238739
# Epoch: [ 0] [ 133/2614] time: 1870.0646, d_loss: 1.15337979794, g_loss: 0.846833705902
# Epoch: [ 0] [ 134/2614] time: 1883.8501, d_loss: 1.21716034412, g_loss: 0.988918483257
# Epoch: [ 0] [ 135/2614] time: 1898.4205, d_loss: 1.19671165943, g_loss: 0.801012933254
# Epoch: [ 0] [ 136/2614] time: 1915.6811, d_loss: 1.27972984314, g_loss: 0.597153425217
# Epoch: [ 0] [ 137/2614] time: 1934.1441, d_loss: 1.36424922943, g_loss: 0.98766541481
# Epoch: [ 0] [ 138/2614] time: 1953.0742, d_loss: 1.29673790932, g_loss: 0.562607645988
# Epoch: [ 0] [ 139/2614] time: 1969.8645, d_loss: 1.23731100559, g_loss: 1.01448011398
# Epoch: [ 0] [ 140/2614] time: 1984.2026, d_loss: 1.284080863, g_loss: 0.778688073158
# Epoch: [ 0] [ 141/2614] time: 1999.1215, d_loss: 1.25485181808, g_loss: 0.739915132523
# Epoch: [ 0] [ 142/2614] time: 2015.5109, d_loss: 1.25642371178, g_loss: 0.957638263702
# Epoch: [ 0] [ 143/2614] time: 2032.1593, d_loss: 1.21354484558, g_loss: 0.799342632294
# Epoch: [ 0] [ 144/2614] time: 2048.3214, d_loss: 1.21870040894, g_loss: 0.768559217453
# Epoch: [ 0] [ 145/2614] time: 2065.3278, d_loss: 1.45621085167, g_loss: 0.453774124384
# Epoch: [ 0] [ 146/2614] time: 2080.5622, d_loss: 1.33800172806, g_loss: 1.03187572956
# Epoch: [ 0] [ 147/2614] time: 2097.5894, d_loss: 1.26354336739, g_loss: 0.813333570957
# Epoch: [ 0] [ 148/2614] time: 2115.1601, d_loss: 1.37204730511, g_loss: 0.984139382839
# Epoch: [ 0] [ 149/2614] time: 2129.7985, d_loss: 1.22819972038, g_loss: 0.526439011097
# Epoch: [ 0] [ 150/2614] time: 2145.8438, d_loss: 1.34710776806, g_loss: 1.22580075264
# Epoch: [ 0] [ 151/2614] time: 2161.5844, d_loss: 1.3345477581, g_loss: 1.1752269268
# Epoch: [ 0] [ 152/2614] time: 2177.0786, d_loss: 1.25651681423, g_loss: 0.525962114334
# Epoch: [ 0] [ 153/2614] time: 2194.1322, d_loss: 1.14208197594, g_loss: 1.0261888504
# Epoch: [ 0] [ 154/2614] time: 2208.5810, d_loss: 1.29758620262, g_loss: 0.866898655891
# Epoch: [ 0] [ 155/2614] time: 2222.2920, d_loss: 1.09872698784, g_loss: 0.937636137009
# Epoch: [ 0] [ 156/2614] time: 2236.0922, d_loss: 1.13637065887, g_loss: 1.02562069893
# Epoch: [ 0] [ 157/2614] time: 2249.9796, d_loss: 1.2387046814, g_loss: 1.15201234818
# Epoch: [ 0] [ 158/2614] time: 2263.8512, d_loss: 1.06248784065, g_loss: 0.832875132561
# Epoch: [ 0] [ 159/2614] time: 2277.9390, d_loss: 1.28691506386, g_loss: 1.42518341541
# Epoch: [ 0] [ 160/2614] time: 2292.4464, d_loss: 1.26989686489, g_loss: 0.603276968002
# Epoch: [ 0] [ 161/2614] time: 2306.5149, d_loss: 1.16178357601, g_loss: 0.721474289894
# Epoch: [ 0] [ 162/2614] time: 2321.4856, d_loss: 1.31488227844, g_loss: 1.13327074051
# Epoch: [ 0] [ 163/2614] time: 2338.3077, d_loss: 1.30915772915, g_loss: 0.449292004108
# Epoch: [ 0] [ 164/2614] time: 2352.6748, d_loss: 1.31916022301, g_loss: 1.34589660168
# Epoch: [ 0] [ 165/2614] time: 2366.7491, d_loss: 1.28526091576, g_loss: 0.798245310783
# Epoch: [ 0] [ 166/2614] time: 2383.0925, d_loss: 1.23934412003, g_loss: 0.621340870857
# Epoch: [ 0] [ 167/2614] time: 2402.2691, d_loss: 1.21355009079, g_loss: 1.0088378191
# Epoch: [ 0] [ 168/2614] time: 2419.9957, d_loss: 1.16678655148, g_loss: 1.09162175655
# Epoch: [ 0] [ 169/2614] time: 2435.1708, d_loss: 1.24900496006, g_loss: 1.35232806206
# Epoch: [ 0] [ 170/2614] time: 2456.5809, d_loss: 1.27859187126, g_loss: 1.08524811268
# Epoch: [ 0] [ 171/2614] time: 2474.1867, d_loss: 1.19692492485, g_loss: 1.08936333656
# Epoch: [ 0] [ 172/2614] time: 2489.2681, d_loss: 1.08814930916, g_loss: 0.976782679558
# Epoch: [ 0] [ 173/2614] time: 2503.7729, d_loss: 1.19663071632, g_loss: 0.682705640793
# Epoch: [ 0] [ 174/2614] time: 2521.7538, d_loss: 1.1515481472, g_loss: 0.655400276184
# Epoch: [ 0] [ 175/2614] time: 2538.2013, d_loss: 1.26154267788, g_loss: 1.15576720238
# Epoch: [ 0] [ 176/2614] time: 2554.4998, d_loss: 1.26472318172, g_loss: 0.524266242981
# Epoch: [ 0] [ 177/2614] time: 2573.3542, d_loss: 1.56875395775, g_loss: 1.73242080212
# Epoch: [ 0] [ 178/2614] time: 2590.3406, d_loss: 1.15089178085, g_loss: 0.656450748444
# Epoch: [ 0] [ 179/2614] time: 2609.7089, d_loss: 1.15111470222, g_loss: 0.9061242342
# Epoch: [ 0] [ 180/2614] time: 2629.2997, d_loss: 1.1698679924, g_loss: 0.691838085651
# Epoch: [ 0] [ 181/2614] time: 2645.6763, d_loss: 1.30819702148, g_loss: 0.654286503792
# Epoch: [ 0] [ 182/2614] time: 2661.7809, d_loss: 1.23714435101, g_loss: 0.670875668526
# Epoch: [ 0] [ 183/2614] time: 2677.8298, d_loss: 1.44143199921, g_loss: 1.61827516556
# Epoch: [ 0] [ 184/2614] time: 2693.3980, d_loss: 1.5190076828, g_loss: 0.352195382118
# Epoch: [ 0] [ 185/2614] time: 2708.7637, d_loss: 1.50279223919, g_loss: 1.78489303589
# Epoch: [ 0] [ 186/2614] time: 2723.9745, d_loss: 1.25121688843, g_loss: 0.645209789276
# Epoch: [ 0] [ 187/2614] time: 2739.3943, d_loss: 1.29635620117, g_loss: 1.69860601425
# Epoch: [ 0] [ 188/2614] time: 2754.7073, d_loss: 1.37189865112, g_loss: 0.626608610153
# Epoch: [ 0] [ 189/2614] time: 2770.1530, d_loss: 1.07143449783, g_loss: 0.935372471809
# Epoch: [ 0] [ 190/2614] time: 2785.7238, d_loss: 1.1458132267, g_loss: 0.974204897881
# Epoch: [ 0] [ 191/2614] time: 2800.8531, d_loss: 1.2673330307, g_loss: 0.535465955734
# Epoch: [ 0] [ 192/2614] time: 2816.1923, d_loss: 1.22201323509, g_loss: 0.950075149536
# Epoch: [ 0] [ 193/2614] time: 2831.5195, d_loss: 1.20514750481, g_loss: 0.8591324687
# Epoch: [ 0] [ 194/2614] time: 2846.9511, d_loss: 1.20084285736, g_loss: 0.651032447815
# Epoch: [ 0] [ 195/2614] time: 2862.0790, d_loss: 1.21316516399, g_loss: 1.24182629585
# Epoch: [ 0] [ 196/2614] time: 2877.4533, d_loss: 1.10633468628, g_loss: 0.871830880642
# Epoch: [ 0] [ 197/2614] time: 2892.7033, d_loss: 1.27433443069, g_loss: 0.746988415718
# Epoch: [ 0] [ 198/2614] time: 2908.3461, d_loss: 1.16305851936, g_loss: 1.26485359669
# Epoch: [ 0] [ 199/2614] time: 2923.5525, d_loss: 1.38312149048, g_loss: 0.908998370171
# Epoch: [ 0] [ 200/2614] time: 2938.5547, d_loss: 1.34998726845, g_loss: 0.459225296974
# Saved model
# Sample saved: True
# Epoch: [ 0] [ 201/2614] time: 2959.1735, d_loss: 1.2581205368, g_loss: 1.38107717037
# Epoch: [ 0] [ 202/2614] time: 2974.9037, d_loss: 1.16257929802, g_loss: 0.705906629562
# Epoch: [ 0] [ 203/2614] time: 2990.2900, d_loss: 1.46045386791, g_loss: 0.866772294044
# Epoch: [ 0] [ 204/2614] time: 3005.5933, d_loss: 1.23722159863, g_loss: 0.559924244881
# Epoch: [ 0] [ 205/2614] time: 3021.4309, d_loss: 1.44612777233, g_loss: 1.29226505756
# Epoch: [ 0] [ 206/2614] time: 3036.7789, d_loss: 1.35596823692, g_loss: 0.47956803441
# Epoch: [ 0] [ 207/2614] time: 3052.4662, d_loss: 1.11275267601, g_loss: 0.953865349293
# Epoch: [ 0] [ 208/2614] time: 3067.6031, d_loss: 1.35699748993, g_loss: 0.889572679996
# Epoch: [ 0] [ 209/2614] time: 3082.9811, d_loss: 1.31694054604, g_loss: 0.59943073988
# Epoch: [ 0] [ 210/2614] time: 3098.3109, d_loss: 1.23118007183, g_loss: 0.900366306305
# Epoch: [ 0] [ 211/2614] time: 3113.6179, d_loss: 1.41721653938, g_loss: 0.992200493813
# Epoch: [ 0] [ 212/2614] time: 3129.0802, d_loss: 1.32635009289, g_loss: 0.57142084837
# Epoch: [ 0] [ 213/2614] time: 3144.6933, d_loss: 1.29118275642, g_loss: 0.654066324234
# Epoch: [ 0] [ 214/2614] time: 3160.1905, d_loss: 1.40133190155, g_loss: 1.55374765396
# Epoch: [ 0] [ 215/2614] time: 3176.1242, d_loss: 1.18152236938, g_loss: 0.712571620941
# Epoch: [ 0] [ 216/2614] time: 3192.1867, d_loss: 1.17271661758, g_loss: 1.03451991081
# Epoch: [ 0] [ 217/2614] time: 3207.8812, d_loss: 1.20337748528, g_loss: 0.647358119488
# Epoch: [ 0] [ 218/2614] time: 3223.1304, d_loss: 1.2311103344, g_loss: 1.21920061111
# Epoch: [ 0] [ 219/2614] time: 3238.6030, d_loss: 1.1366481781, g_loss: 0.772116065025
# Epoch: [ 0] [ 220/2614] time: 3254.1828, d_loss: 1.08610701561, g_loss: 0.806587874889
# Epoch: [ 0] [ 221/2614] time: 3270.2537, d_loss: 1.14915847778, g_loss: 1.07092690468
# Epoch: [ 0] [ 222/2614] time: 3285.9744, d_loss: 1.17523682117, g_loss: 0.98593878746
# Epoch: [ 0] [ 223/2614] time: 3301.6524, d_loss: 1.04759383202, g_loss: 1.11682653427
# Epoch: [ 0] [ 224/2614] time: 3317.5376, d_loss: 1.17927980423, g_loss: 0.854024410248
# Epoch: [ 0] [ 225/2614] time: 3333.0336, d_loss: 1.50544905663, g_loss: 1.41213870049
# Epoch: [ 0] [ 226/2614] time: 3348.8536, d_loss: 1.49363040924, g_loss: 0.325346440077
# Epoch: [ 0] [ 227/2614] time: 3364.5840, d_loss: 1.23371720314, g_loss: 1.37674200535
# Epoch: [ 0] [ 228/2614] time: 3380.8199, d_loss: 1.3718713522, g_loss: 0.444963634014
# Epoch: [ 0] [ 229/2614] time: 3396.3018, d_loss: 1.19261169434, g_loss: 0.934572458267
# Epoch: [ 0] [ 230/2614] time: 3412.2898, d_loss: 1.2362215519, g_loss: 1.01514339447
# Epoch: [ 0] [ 231/2614] time: 3427.9576, d_loss: 1.29440808296, g_loss: 0.457700520754
# Epoch: [ 0] [ 232/2614] time: 3443.5953, d_loss: 1.14760661125, g_loss: 1.09007191658
# Epoch: [ 0] [ 233/2614] time: 3459.3003, d_loss: 1.26978552341, g_loss: 0.955391526222
# Epoch: [ 0] [ 234/2614] time: 3474.9559, d_loss: 1.26331162453, g_loss: 0.587138652802
# Epoch: [ 0] [ 235/2614] time: 3491.2822, d_loss: 1.7414393425, g_loss: 1.8147623539
# Epoch: [ 0] [ 236/2614] time: 3507.6316, d_loss: 1.1754732132, g_loss: 0.717820525169
# Epoch: [ 0] [ 237/2614] time: 3523.5848, d_loss: 1.26022744179, g_loss: 1.13408946991
# Epoch: [ 0] [ 238/2614] time: 3539.2188, d_loss: 1.1936147213, g_loss: 1.12995553017
# Epoch: [ 0] [ 239/2614] time: 3554.9490, d_loss: 1.27007770538, g_loss: 0.764469444752
# Epoch: [ 0] [ 240/2614] time: 3570.6208, d_loss: 1.29001665115, g_loss: 1.61512517929
# Epoch: [ 0] [ 241/2614] time: 3586.4925, d_loss: 1.29830110073, g_loss: 0.527677416801
# Epoch: [ 0] [ 242/2614] time: 3602.2367, d_loss: 1.2190580368, g_loss: 0.815190553665
# Epoch: [ 0] [ 243/2614] time: 3618.1240, d_loss: 1.18196189404, g_loss: 0.946224689484
# Epoch: [ 0] [ 244/2614] time: 3634.4884, d_loss: 1.42113661766, g_loss: 0.425196945667
# Epoch: [ 0] [ 245/2614] time: 3650.4537, d_loss: 1.11361289024, g_loss: 0.968906998634
# Epoch: [ 0] [ 246/2614] time: 3666.5047, d_loss: 1.24414753914, g_loss: 0.952896416187
# Epoch: [ 0] [ 247/2614] time: 3682.3600, d_loss: 1.40305566788, g_loss: 0.408542364836
# Epoch: [ 0] [ 248/2614] time: 3698.2567, d_loss: 1.37769019604, g_loss: 1.13746571541
# Epoch: [ 0] [ 249/2614] time: 3714.3674, d_loss: 1.31935119629, g_loss: 0.567655444145
# Epoch: [ 0] [ 250/2614] time: 3730.4844, d_loss: 1.15877580643, g_loss: 0.932925999165
# Epoch: [ 0] [ 251/2614] time: 3746.8092, d_loss: 1.22045767307, g_loss: 0.652001619339
# Epoch: [ 0] [ 252/2614] time: 3762.7407, d_loss: 1.34868323803, g_loss: 1.04292976856
# Epoch: [ 0] [ 253/2614] time: 3778.8773, d_loss: 1.34936749935, g_loss: 1.16423010826
# Epoch: [ 0] [ 254/2614] time: 3795.1787, d_loss: 1.26947927475, g_loss: 0.552468955517
# Epoch: [ 0] [ 255/2614] time: 3811.5306, d_loss: 1.55001103878, g_loss: 1.72308731079
# Epoch: [ 0] [ 256/2614] time: 3827.7424, d_loss: 1.16530561447, g_loss: 0.854679703712
# Epoch: [ 0] [ 257/2614] time: 3844.1370, d_loss: 1.11151123047, g_loss: 0.814278483391
# Epoch: [ 0] [ 258/2614] time: 3860.2739, d_loss: 1.18826293945, g_loss: 0.924110352993
# Epoch: [ 0] [ 259/2614] time: 3876.7835, d_loss: 1.3335506916, g_loss: 0.896718859673
# Epoch: [ 0] [ 260/2614] time: 3893.1389, d_loss: 1.34830951691, g_loss: 0.496673762798
# Epoch: [ 0] [ 261/2614] time: 3909.5560, d_loss: 1.16110181808, g_loss: 0.923111557961
# Epoch: [ 0] [ 262/2614] time: 3926.0173, d_loss: 1.21143007278, g_loss: 0.973938703537
# Epoch: [ 0] [ 263/2614] time: 3942.1415, d_loss: 1.40450549126, g_loss: 0.947643578053
# Epoch: [ 0] [ 264/2614] time: 3958.5253, d_loss: 1.21557271481, g_loss: 0.63290220499
# Epoch: [ 0] [ 265/2614] time: 3974.5010, d_loss: 1.12991297245, g_loss: 0.792747378349
# Epoch: [ 0] [ 266/2614] time: 3991.1407, d_loss: 1.07244980335, g_loss: 0.910128712654
# Epoch: [ 0] [ 267/2614] time: 4007.4311, d_loss: 1.23984742165, g_loss: 1.13638281822
# Epoch: [ 0] [ 268/2614] time: 4023.7916, d_loss: 1.21428275108, g_loss: 0.601353764534
# Epoch: [ 0] [ 269/2614] time: 4039.7367, d_loss: 1.38498926163, g_loss: 1.62673592567
# Epoch: [ 0] [ 270/2614] time: 4058.7816, d_loss: 1.20572197437, g_loss: 0.648393154144
# Epoch: [ 0] [ 271/2614] time: 4076.0185, d_loss: 1.23443496227, g_loss: 1.10887563229
# Epoch: [ 0] [ 272/2614] time: 4092.7987, d_loss: 1.29529881477, g_loss: 0.579494595528
# Epoch: [ 0] [ 273/2614] time: 4109.5937, d_loss: 1.21588301659, g_loss: 0.732458353043
# Epoch: [ 0] [ 274/2614] time: 4126.2490, d_loss: 1.25375401974, g_loss: 0.774058103561
# Epoch: [ 0] [ 275/2614] time: 4142.9265, d_loss: 1.15360569954, g_loss: 0.730654597282
# Epoch: [ 0] [ 276/2614] time: 4159.5358, d_loss: 1.22615456581, g_loss: 0.60431855917
# Epoch: [ 0] [ 277/2614] time: 4176.5540, d_loss: 1.28319728374, g_loss: 1.05113387108
# Epoch: [ 0] [ 278/2614] time: 4193.4941, d_loss: 1.15055894852, g_loss: 0.755527555943
# Epoch: [ 0] [ 279/2614] time: 4210.4915, d_loss: 1.24576258659, g_loss: 1.03806960583
# Epoch: [ 0] [ 280/2614] time: 4227.4113, d_loss: 1.52533173561, g_loss: 1.55084204674
# Epoch: [ 0] [ 281/2614] time: 4245.1667, d_loss: 1.23557603359, g_loss: 0.499050617218
# Epoch: [ 0] [ 282/2614] time: 4262.1939, d_loss: 1.10244011879, g_loss: 0.951879024506
# Epoch: [ 0] [ 283/2614] time: 4279.3237, d_loss: 1.56882345676, g_loss: 1.93276751041
# Epoch: [ 0] [ 284/2614] time: 4296.1709, d_loss: 1.39126801491, g_loss: 0.439047306776
# Epoch: [ 0] [ 285/2614] time: 4313.0286, d_loss: 1.38384962082, g_loss: 1.63377475739
# Epoch: [ 0] [ 286/2614] time: 4330.2672, d_loss: 1.33241915703, g_loss: 0.542509913445
# Epoch: [ 0] [ 287/2614] time: 4346.8118, d_loss: 1.17778992653, g_loss: 0.907286763191
# Epoch: [ 0] [ 288/2614] time: 4363.4395, d_loss: 1.23743009567, g_loss: 0.654228925705
# Epoch: [ 0] [ 289/2614] time: 4379.3992, d_loss: 1.33114159107, g_loss: 1.07705140114
# Epoch: [ 0] [ 290/2614] time: 4395.3138, d_loss: 1.33110582829, g_loss: 0.536714911461
# Epoch: [ 0] [ 291/2614] time: 4410.7839, d_loss: 1.252607584, g_loss: 1.31290173531
# Epoch: [ 0] [ 292/2614] time: 4426.5583, d_loss: 1.26644861698, g_loss: 0.568548440933
# Epoch: [ 0] [ 293/2614] time: 4441.9935, d_loss: 1.19935822487, g_loss: 0.992121338844
# Epoch: [ 0] [ 294/2614] time: 4457.4266, d_loss: 1.23517179489, g_loss: 0.693590521812
# Epoch: [ 0] [ 295/2614] time: 4473.1475, d_loss: 1.2620947361, g_loss: 0.982999265194
# Epoch: [ 0] [ 296/2614] time: 4488.7972, d_loss: 1.28445971012, g_loss: 0.814829230309
# Epoch: [ 0] [ 297/2614] time: 4504.2947, d_loss: 1.20375573635, g_loss: 0.903364896774
# Epoch: [ 0] [ 298/2614] time: 4519.2517, d_loss: 1.4339401722, g_loss: 0.834797501564
# Epoch: [ 0] [ 299/2614] time: 4535.9221, d_loss: 1.3042832613, g_loss: 0.575409531593
# Epoch: [ 0] [ 300/2614] time: 4554.2728, d_loss: 1.28898882866, g_loss: 1.11691129208
# Saved model
# Sample saved: True
# Epoch: [ 0] [ 301/2614] time: 4581.1880, d_loss: 1.13499820232, g_loss: 0.729027092457
# Epoch: [ 0] [ 302/2614] time: 4602.2115, d_loss: 1.12907600403, g_loss: 0.751300811768
# Epoch: [ 0] [ 303/2614] time: 4627.2143, d_loss: 1.29078400135, g_loss: 1.40698504448
# Epoch: [ 0] [ 304/2614] time: 4644.5960, d_loss: 1.12424683571, g_loss: 0.84049654007
# Epoch: [ 0] [ 305/2614] time: 4660.6885, d_loss: 1.12936878204, g_loss: 0.852699279785
# Epoch: [ 0] [ 306/2614] time: 4676.8019, d_loss: 1.11972570419, g_loss: 0.72819852829
# Epoch: [ 0] [ 307/2614] time: 4693.0836, d_loss: 1.24976027012, g_loss: 0.94227284193
# Epoch: [ 0] [ 308/2614] time: 4709.1485, d_loss: 1.25602138042, g_loss: 0.695688962936
# Epoch: [ 0] [ 309/2614] time: 4725.7158, d_loss: 1.10583019257, g_loss: 0.899086833
# Epoch: [ 0] [ 310/2614] time: 4741.5539, d_loss: 1.24867129326, g_loss: 1.28720927238
# Epoch: [ 0] [ 311/2614] time: 4757.4667, d_loss: 1.10388362408, g_loss: 0.744133591652
# Epoch: [ 0] [ 312/2614] time: 4773.0314, d_loss: 1.10968756676, g_loss: 0.823761045933
# Epoch: [ 0] [ 313/2614] time: 4788.9667, d_loss: 1.207426548, g_loss: 0.862749278545
# Epoch: [ 0] [ 314/2614] time: 4804.7941, d_loss: 1.15637898445, g_loss: 0.645332932472
# Epoch: [ 0] [ 315/2614] time: 4820.6146, d_loss: 1.08407866955, g_loss: 1.03165888786
# Epoch: [ 0] [ 316/2614] time: 4836.6462, d_loss: 1.16179466248, g_loss: 0.767734527588
# Epoch: [ 0] [ 317/2614] time: 4853.2052, d_loss: 1.12720191479, g_loss: 0.898436307907
# Epoch: [ 0] [ 318/2614] time: 4869.6533, d_loss: 1.11710906029, g_loss: 0.786454916
# Epoch: [ 0] [ 319/2614] time: 4885.9577, d_loss: 1.25778412819, g_loss: 0.478260934353
# Epoch: [ 0] [ 320/2614] time: 4902.3882, d_loss: 1.23651444912, g_loss: 1.61136198044
# Epoch: [ 0] [ 321/2614] time: 4918.3861, d_loss: 1.16951131821, g_loss: 0.604697108269
# Epoch: [ 0] [ 322/2614] time: 4934.2070, d_loss: 1.0892124176, g_loss: 1.06025099754
# Epoch: [ 0] [ 323/2614] time: 4950.2125, d_loss: 1.17161929607, g_loss: 0.903182506561
# Epoch: [ 0] [ 324/2614] time: 4967.0263, d_loss: 1.23765623569, g_loss: 1.03939390182
# Epoch: [ 0] [ 325/2614] time: 4983.6238, d_loss: 1.25366997719, g_loss: 0.713075876236
# Epoch: [ 0] [ 326/2614] time: 4999.9574, d_loss: 1.14199447632, g_loss: 1.06025850773
# Epoch: [ 0] [ 327/2614] time: 5016.1327, d_loss: 1.37535226345, g_loss: 1.26017832756
# Epoch: [ 0] [ 328/2614] time: 5031.9039, d_loss: 1.2220864296, g_loss: 0.782766640186
# Epoch: [ 0] [ 329/2614] time: 5047.7789, d_loss: 1.23743510246, g_loss: 0.685628414154
# Epoch: [ 0] [ 330/2614] time: 5063.6372, d_loss: 1.25522553921, g_loss: 0.950232625008
# Epoch: [ 0] [ 331/2614] time: 5079.6377, d_loss: 1.27673470974, g_loss: 0.642931938171
# Epoch: [ 0] [ 332/2614] time: 5095.6880, d_loss: 1.19976580143, g_loss: 0.877813577652
# Epoch: [ 0] [ 333/2614] time: 5111.5129, d_loss: 1.51990699768, g_loss: 1.58368825912
# Epoch: [ 0] [ 334/2614] time: 5127.2807, d_loss: 1.29055809975, g_loss: 0.602612495422
# Epoch: [ 0] [ 335/2614] time: 5142.9617, d_loss: 1.16905343533, g_loss: 0.813804745674
# Epoch: [ 0] [ 336/2614] time: 5159.0396, d_loss: 1.20863389969, g_loss: 1.16863369942
# Epoch: [ 0] [ 337/2614] time: 5174.7626, d_loss: 1.31310081482, g_loss: 0.451445251703
# Epoch: [ 0] [ 338/2614] time: 5190.2706, d_loss: 1.15275490284, g_loss: 1.06987190247
# Epoch: [ 0] [ 339/2614] time: 5206.1607, d_loss: 1.19521737099, g_loss: 0.714752733707
# Epoch: [ 0] [ 340/2614] time: 5221.8547, d_loss: 1.18554735184, g_loss: 0.875661551952
# Epoch: [ 0] [ 341/2614] time: 5237.5681, d_loss: 1.33262431622, g_loss: 0.942542314529
# Epoch: [ 0] [ 342/2614] time: 5253.0827, d_loss: 1.29787778854, g_loss: 0.558114886284
# Epoch: [ 0] [ 343/2614] time: 5268.6122, d_loss: 1.35780143738, g_loss: 1.50068295002
# Epoch: [ 0] [ 344/2614] time: 5284.0783, d_loss: 1.2004711628, g_loss: 0.697230815887
# Epoch: [ 0] [ 345/2614] time: 5300.0028, d_loss: 1.28081929684, g_loss: 0.73407137394
# Epoch: [ 0] [ 346/2614] time: 5315.5784, d_loss: 1.14620566368, g_loss: 0.939229130745
# Epoch: [ 0] [ 347/2614] time: 5331.8264, d_loss: 1.30755782127, g_loss: 1.18040835857
# Epoch: [ 0] [ 348/2614] time: 5347.2904, d_loss: 1.14284229279, g_loss: 0.812693238258
# Epoch: [ 0] [ 349/2614] time: 5363.0748, d_loss: 1.17317926884, g_loss: 0.71232008934
# Epoch: [ 0] [ 350/2614] time: 5378.4416, d_loss: 1.37061834335, g_loss: 1.4633462429
# Epoch: [ 0] [ 351/2614] time: 5394.2728, d_loss: 1.27007782459, g_loss: 0.600844860077
# Epoch: [ 0] [ 352/2614] time: 5412.0853, d_loss: 1.27951693535, g_loss: 0.518477797508
# Epoch: [ 0] [ 353/2614] time: 5426.8284, d_loss: 1.20275974274, g_loss: 1.19845879078
# Epoch: [ 0] [ 354/2614] time: 5445.3998, d_loss: 1.15787923336, g_loss: 0.80400621891
# Epoch: [ 0] [ 355/2614] time: 5467.6001, d_loss: 1.15545010567, g_loss: 0.86096906662
# Epoch: [ 0] [ 356/2614] time: 5485.7236, d_loss: 1.08772432804, g_loss: 1.06463003159
# Epoch: [ 0] [ 357/2614] time: 5501.7565, d_loss: 1.14064335823, g_loss: 0.905573308468
# Epoch: [ 0] [ 358/2614] time: 5517.6774, d_loss: 1.25828945637, g_loss: 1.11922311783
# Epoch: [ 0] [ 359/2614] time: 5533.7682, d_loss: 1.22538924217, g_loss: 1.17340612411
# Epoch: [ 0] [ 360/2614] time: 5549.7037, d_loss: 1.19458925724, g_loss: 0.574101448059
# Epoch: [ 0] [ 361/2614] time: 5565.9258, d_loss: 1.3461830616, g_loss: 2.01216459274
# Epoch: [ 0] [ 362/2614] time: 5582.3952, d_loss: 1.1988325119, g_loss: 0.777250409126
# Epoch: [ 0] [ 363/2614] time: 5599.3836, d_loss: 1.11657714844, g_loss: 1.02495074272
# Epoch: [ 0] [ 364/2614] time: 5615.5163, d_loss: 1.27688968182, g_loss: 0.585920810699
# Epoch: [ 0] [ 365/2614] time: 5631.8180, d_loss: 1.14731860161, g_loss: 0.664986848831
# Epoch: [ 0] [ 366/2614] time: 5647.5840, d_loss: 1.22184729576, g_loss: 0.967097222805
# Epoch: [ 0] [ 367/2614] time: 5663.5766, d_loss: 1.1209615469, g_loss: 0.812510967255
# Epoch: [ 0] [ 368/2614] time: 5679.4914, d_loss: 1.24007105827, g_loss: 0.752073049545
# Epoch: [ 0] [ 369/2614] time: 5696.5910, d_loss: 1.29856562614, g_loss: 1.17648160458
# Epoch: [ 0] [ 370/2614] time: 5714.8100, d_loss: 1.20174503326, g_loss: 0.973907113075
# Epoch: [ 0] [ 371/2614] time: 5730.7831, d_loss: 1.14898753166, g_loss: 0.846231222153
# Epoch: [ 0] [ 372/2614] time: 5746.7800, d_loss: 1.38132715225, g_loss: 1.60563623905
# Epoch: [ 0] [ 373/2614] time: 5762.7235, d_loss: 1.35518062115, g_loss: 0.454961121082
# Epoch: [ 0] [ 374/2614] time: 5778.7508, d_loss: 1.25304722786, g_loss: 1.40366601944
# Epoch: [ 0] [ 375/2614] time: 5794.2814, d_loss: 1.28562569618, g_loss: 0.782335281372
# Epoch: [ 0] [ 376/2614] time: 5810.2440, d_loss: 1.29626882076, g_loss: 0.535661101341
# Epoch: [ 0] [ 377/2614] time: 5825.9157, d_loss: 1.22302985191, g_loss: 1.33203220367
# Epoch: [ 0] [ 378/2614] time: 5841.3550, d_loss: 1.28147339821, g_loss: 0.578832030296
# Epoch: [ 0] [ 379/2614] time: 5856.7468, d_loss: 1.20554256439, g_loss: 0.683026313782
# Epoch: [ 0] [ 380/2614] time: 5871.9608, d_loss: 1.24875819683, g_loss: 1.0326590538
# Epoch: [ 0] [ 381/2614] time: 5887.5131, d_loss: 1.19044172764, g_loss: 0.798010349274
# Epoch: [ 0] [ 382/2614] time: 5902.8213, d_loss: 1.15089178085, g_loss: 0.815907478333
# Epoch: [ 0] [ 383/2614] time: 5917.9151, d_loss: 1.17557501793, g_loss: 0.996889531612
# Epoch: [ 0] [ 384/2614] time: 5933.5503, d_loss: 1.19814670086, g_loss: 0.661696434021
# Epoch: [ 0] [ 385/2614] time: 5948.5868, d_loss: 1.54851770401, g_loss: 2.17850422859
# Epoch: [ 0] [ 386/2614] time: 5963.6443, d_loss: 1.20913827419, g_loss: 0.552358627319
# Epoch: [ 0] [ 387/2614] time: 5978.5842, d_loss: 1.27652072906, g_loss: 1.1626200676
# Epoch: [ 0] [ 388/2614] time: 5993.8397, d_loss: 1.21223723888, g_loss: 0.712710499763
# Epoch: [ 0] [ 389/2614] time: 6008.7705, d_loss: 1.33015465736, g_loss: 0.499608814716
# Epoch: [ 0] [ 390/2614] time: 6023.6988, d_loss: 1.41022133827, g_loss: 1.71788311005
# Epoch: [ 0] [ 391/2614] time: 6038.4698, d_loss: 1.35659360886, g_loss: 0.486736744642
# Epoch: [ 0] [ 392/2614] time: 6053.9229, d_loss: 1.04017603397, g_loss: 1.08074045181
# Epoch: [ 0] [ 393/2614] time: 6069.1821, d_loss: 1.44270980358, g_loss: 1.56851518154
# Epoch: [ 0] [ 394/2614] time: 6084.1389, d_loss: 1.29248058796, g_loss: 0.521025896072
# Epoch: [ 0] [ 395/2614] time: 6099.4403, d_loss: 1.33297717571, g_loss: 0.445206671953
# Epoch: [ 0] [ 396/2614] time: 6114.3685, d_loss: 1.08607757092, g_loss: 1.22326135635
# Epoch: [ 0] [ 397/2614] time: 6129.2139, d_loss: 1.29022407532, g_loss: 0.606191456318
# Epoch: [ 0] [ 398/2614] time: 6144.0023, d_loss: 1.44185781479, g_loss: 1.11404681206
# Epoch: [ 0] [ 399/2614] time: 6158.5849, d_loss: 1.29387664795, g_loss: 0.789910435677
# Epoch: [ 0] [ 400/2614] time: 6173.6192, d_loss: 1.26016283035, g_loss: 0.940627574921
# Saved model
# Sample saved: True
# Epoch: [ 0] [ 401/2614] time: 6193.6725, d_loss: 1.27859067917, g_loss: 1.06229889393
# Epoch: [ 0] [ 402/2614] time: 6209.2371, d_loss: 1.38343930244, g_loss: 0.587814331055
# Epoch: [ 0] [ 403/2614] time: 6224.5636, d_loss: 1.25249409676, g_loss: 1.00636005402
# Epoch: [ 0] [ 404/2614] time: 6239.3440, d_loss: 1.39434993267, g_loss: 1.31555438042
# Epoch: [ 0] [ 405/2614] time: 6253.9197, d_loss: 1.2427315712, g_loss: 0.576845169067
# Epoch: [ 0] [ 406/2614] time: 6268.3254, d_loss: 1.33836877346, g_loss: 1.13460052013
# Epoch: [ 0] [ 407/2614] time: 6283.3064, d_loss: 1.16424417496, g_loss: 0.80584859848
# Epoch: [ 0] [ 408/2614] time: 6298.1718, d_loss: 1.14867019653, g_loss: 0.726700901985
# Epoch: [ 0] [ 409/2614] time: 6313.0682, d_loss: 1.26537084579, g_loss: 1.42052817345
# Epoch: [ 0] [ 410/2614] time: 6327.7803, d_loss: 1.21122407913, g_loss: 1.01574397087
# Epoch: [ 0] [ 411/2614] time: 6342.2949, d_loss: 1.11904704571, g_loss: 0.827808856964
# Epoch: [ 0] [ 412/2614] time: 6357.0309, d_loss: 1.27054393291, g_loss: 0.632427692413
# Epoch: [ 0] [ 413/2614] time: 6371.5554, d_loss: 1.2646009922, g_loss: 0.64565205574
# Epoch: [ 0] [ 414/2614] time: 6386.1286, d_loss: 1.26081442833, g_loss: 1.02276742458
# Epoch: [ 0] [ 415/2614] time: 6400.4566, d_loss: 1.54409599304, g_loss: 0.378319144249
# Epoch: [ 0] [ 416/2614] time: 6415.0883, d_loss: 1.15890681744, g_loss: 1.17959570885
# Epoch: [ 0] [ 417/2614] time: 6429.7896, d_loss: 1.23320174217, g_loss: 0.798065304756
# Epoch: [ 0] [ 418/2614] time: 6444.2421, d_loss: 1.26317059994, g_loss: 0.721065163612
# Epoch: [ 0] [ 419/2614] time: 6458.7830, d_loss: 1.37164020538, g_loss: 1.40984487534
# Epoch: [ 0] [ 420/2614] time: 6473.3805, d_loss: 1.2077974081, g_loss: 0.77721196413
# Epoch: [ 0] [ 421/2614] time: 6488.0962, d_loss: 1.20649576187, g_loss: 0.716827392578
# Epoch: [ 0] [ 422/2614] time: 6502.8730, d_loss: 1.18681001663, g_loss: 0.642336249352
# Epoch: [ 0] [ 423/2614] time: 6517.2494, d_loss: 1.22322595119, g_loss: 1.31834316254
# Epoch: [ 0] [ 424/2614] time: 6531.8048, d_loss: 1.29501676559, g_loss: 0.497874438763
# Epoch: [ 0] [ 425/2614] time: 6546.4071, d_loss: 1.38122057915, g_loss: 1.4171807766
# Epoch: [ 0] [ 426/2614] time: 6560.7984, d_loss: 1.21363687515, g_loss: 0.680500864983
# Epoch: [ 0] [ 427/2614] time: 6575.2467, d_loss: 1.33281636238, g_loss: 0.667644619942
# Epoch: [ 0] [ 428/2614] time: 6589.5918, d_loss: 1.47207188606, g_loss: 1.37110173702
# Epoch: [ 0] [ 429/2614] time: 6604.0054, d_loss: 1.25467157364, g_loss: 0.601707696915
# Epoch: [ 0] [ 430/2614] time: 6618.2721, d_loss: 1.20654535294, g_loss: 0.634176671505
# Epoch: [ 0] [ 431/2614] time: 6632.5553, d_loss: 1.16756939888, g_loss: 1.53333926201
# Epoch: [ 0] [ 432/2614] time: 6646.7361, d_loss: 1.33507370949, g_loss: 1.03116559982
# Epoch: [ 0] [ 433/2614] time: 6661.1032, d_loss: 1.3795093298, g_loss: 0.413387715816
# Epoch: [ 0] [ 434/2614] time: 6675.8166, d_loss: 1.10273814201, g_loss: 1.40218865871
# Epoch: [ 0] [ 435/2614] time: 6690.0907, d_loss: 1.34975755215, g_loss: 0.876103043556
# Epoch: [ 0] [ 436/2614] time: 6704.8301, d_loss: 1.21721732616, g_loss: 0.620526790619
# Epoch: [ 0] [ 437/2614] time: 6719.1269, d_loss: 1.45145630836, g_loss: 1.68658804893
# Epoch: [ 0] [ 438/2614] time: 6733.4332, d_loss: 1.34653007984, g_loss: 0.53706407547
# Epoch: [ 0] [ 439/2614] time: 6747.8143, d_loss: 1.22199749947, g_loss: 1.28336596489
# Epoch: [ 0] [ 440/2614] time: 6762.1749, d_loss: 1.26663446426, g_loss: 1.12328124046
# Epoch: [ 0] [ 441/2614] time: 6776.6533, d_loss: 1.19963002205, g_loss: 0.534651935101
# Epoch: [ 0] [ 442/2614] time: 6791.4581, d_loss: 1.4214861393, g_loss: 1.47556197643
# Epoch: [ 0] [ 443/2614] time: 6806.0171, d_loss: 1.33861923218, g_loss: 0.819410443306
# Epoch: [ 0] [ 444/2614] time: 6820.3981, d_loss: 1.40401339531, g_loss: 1.24490749836
# Epoch: [ 0] [ 445/2614] time: 6834.6746, d_loss: 1.21658039093, g_loss: 1.31786382198
# Epoch: [ 0] [ 446/2614] time: 6849.1491, d_loss: 1.35937213898, g_loss: 0.468264698982
# Epoch: [ 0] [ 447/2614] time: 6863.3979, d_loss: 1.57182335854, g_loss: 1.96580481529
# Epoch: [ 0] [ 448/2614] time: 6877.7709, d_loss: 1.268253088, g_loss: 0.627472341061
# Epoch: [ 0] [ 449/2614] time: 6892.1529, d_loss: 1.2718026638, g_loss: 1.43896627426
# Epoch: [ 0] [ 450/2614] time: 6906.3063, d_loss: 1.32444989681, g_loss: 0.601154506207
# Epoch: [ 0] [ 451/2614] time: 6921.3349, d_loss: 1.23689222336, g_loss: 0.562650442123
# Epoch: [ 0] [ 452/2614] time: 6935.6627, d_loss: 1.21464896202, g_loss: 1.16638672352
# Epoch: [ 0] [ 453/2614] time: 6950.1872, d_loss: 1.26262402534, g_loss: 0.616722106934
# Epoch: [ 0] [ 454/2614] time: 6964.4424, d_loss: 1.33642697334, g_loss: 0.540130078793
# Epoch: [ 0] [ 455/2614] time: 6978.8100, d_loss: 1.42770695686, g_loss: 1.33789348602
# Epoch: [ 0] [ 456/2614] time: 6993.3510, d_loss: 1.28738498688, g_loss: 0.565662503242
# Epoch: [ 0] [ 457/2614] time: 7007.7762, d_loss: 1.21705651283, g_loss: 1.02223002911
# Epoch: [ 0] [ 458/2614] time: 7022.1489, d_loss: 1.17864251137, g_loss: 0.884345173836
# Epoch: [ 0] [ 459/2614] time: 7037.0138, d_loss: 1.1944745779, g_loss: 0.67622923851
# Epoch: [ 0] [ 460/2614] time: 7051.3099, d_loss: 1.28157949448, g_loss: 1.30833208561
# Epoch: [ 0] [ 461/2614] time: 7065.7463, d_loss: 1.26212143898, g_loss: 0.77468085289
# Epoch: [ 0] [ 462/2614] time: 7080.0994, d_loss: 1.26656961441, g_loss: 0.59919154644
# Epoch: [ 0] [ 463/2614] time: 7094.8750, d_loss: 1.32985210419, g_loss: 1.15665841103
# Epoch: [ 0] [ 464/2614] time: 7109.4902, d_loss: 1.43539118767, g_loss: 1.27949118614
# Epoch: [ 0] [ 465/2614] time: 7124.1046, d_loss: 1.29538989067, g_loss: 0.54293012619
# Epoch: [ 0] [ 466/2614] time: 7138.6717, d_loss: 1.28663802147, g_loss: 1.65035176277
# Epoch: [ 0] [ 467/2614] time: 7153.4403, d_loss: 1.18216919899, g_loss: 0.724154353142
# Epoch: [ 0] [ 468/2614] time: 7167.9152, d_loss: 1.31782019138, g_loss: 1.28041052818
# Epoch: [ 0] [ 469/2614] time: 7183.1730, d_loss: 1.16366791725, g_loss: 0.762431502342
# Epoch: [ 0] [ 470/2614] time: 7198.8476, d_loss: 1.31489706039, g_loss: 0.53715544939
# Epoch: [ 0] [ 471/2614] time: 7214.7878, d_loss: 1.55200862885, g_loss: 1.46569657326
# Epoch: [ 0] [ 472/2614] time: 7229.4480, d_loss: 1.28632760048, g_loss: 0.575040459633
# Epoch: [ 0] [ 473/2614] time: 7244.1320, d_loss: 1.27288520336, g_loss: 1.10704660416
# Epoch: [ 0] [ 474/2614] time: 7258.7588, d_loss: 1.34165525436, g_loss: 0.851347446442
# Epoch: [ 0] [ 475/2614] time: 7273.5896, d_loss: 1.27872252464, g_loss: 0.663692116737
# Epoch: [ 0] [ 476/2614] time: 7288.2691, d_loss: 1.38353312016, g_loss: 1.12588143349
# Epoch: [ 0] [ 477/2614] time: 7302.9591, d_loss: 1.29585814476, g_loss: 1.10793745518
# Epoch: [ 0] [ 478/2614] time: 7317.5427, d_loss: 1.3674377203, g_loss: 0.532457470894
# Epoch: [ 0] [ 479/2614] time: 7332.2514, d_loss: 1.37200856209, g_loss: 1.17966866493
# Epoch: [ 0] [ 480/2614] time: 7346.9997, d_loss: 1.58738470078, g_loss: 0.393327772617
# Epoch: [ 0] [ 481/2614] time: 7361.8778, d_loss: 1.23620927334, g_loss: 0.929509103298
# Epoch: [ 0] [ 482/2614] time: 7376.2639, d_loss: 1.58091330528, g_loss: 1.41573011875
# Epoch: [ 0] [ 483/2614] time: 7391.1865, d_loss: 1.31744480133, g_loss: 0.595922410488
# Epoch: [ 0] [ 484/2614] time: 7406.5030, d_loss: 1.39013004303, g_loss: 0.937992990017
# Epoch: [ 0] [ 485/2614] time: 7421.1007, d_loss: 1.31301677227, g_loss: 0.889574170113
# Epoch: [ 0] [ 486/2614] time: 7435.9197, d_loss: 1.08666205406, g_loss: 0.904693126678
# Epoch: [ 0] [ 487/2614] time: 7450.5267, d_loss: 1.30711746216, g_loss: 1.41645264626
# Epoch: [ 0] [ 488/2614] time: 7465.1648, d_loss: 1.19743180275, g_loss: 0.566017627716
# Epoch: [ 0] [ 489/2614] time: 7479.9727, d_loss: 1.62201797962, g_loss: 1.80897009373
# Epoch: [ 0] [ 490/2614] time: 7494.5422, d_loss: 1.19033205509, g_loss: 0.716850757599
# Epoch: [ 0] [ 491/2614] time: 7509.2606, d_loss: 1.31466531754, g_loss: 0.524934351444
# Epoch: [ 0] [ 492/2614] time: 7524.2482, d_loss: 1.34636390209, g_loss: 1.76484441757
# Epoch: [ 0] [ 493/2614] time: 7539.0779, d_loss: 1.2063729763, g_loss: 0.635973930359
# Epoch: [ 0] [ 494/2614] time: 7553.6703, d_loss: 1.2489323616, g_loss: 0.973165988922
# Epoch: [ 0] [ 495/2614] time: 7568.4876, d_loss: 1.35407412052, g_loss: 0.861684918404
# Epoch: [ 0] [ 496/2614] time: 7583.1506, d_loss: 1.23380529881, g_loss: 0.850763916969
# Epoch: [ 0] [ 497/2614] time: 7597.8024, d_loss: 1.43696200848, g_loss: 1.41209042072
# Epoch: [ 0] [ 498/2614] time: 7612.5431, d_loss: 1.43565654755, g_loss: 0.391155213118
# Epoch: [ 0] [ 499/2614] time: 7627.0660, d_loss: 1.42222189903, g_loss: 1.44726979733
# Epoch: [ 0] [ 500/2614] time: 7642.0193, d_loss: 1.19685709476, g_loss: 0.889170885086
# Saved model
# Sample saved: True
# Epoch: [ 0] [ 501/2614] time: 7661.7963, d_loss: 1.14549064636, g_loss: 0.839235901833
# Epoch: [ 0] [ 502/2614] time: 7676.5386, d_loss: 1.13078689575, g_loss: 0.981864392757
# Epoch: [ 0] [ 503/2614] time: 7691.4202, d_loss: 1.15689063072, g_loss: 0.786398887634
# Epoch: [ 0] [ 504/2614] time: 7705.7458, d_loss: 1.18834090233, g_loss: 0.83261436224
# Epoch: [ 0] [ 505/2614] time: 7720.1984, d_loss: 1.13099610806, g_loss: 0.740994572639
# Epoch: [ 0] [ 506/2614] time: 7734.6595, d_loss: 1.14822030067, g_loss: 0.903652906418
# Epoch: [ 0] [ 507/2614] time: 7749.2523, d_loss: 1.20787787437, g_loss: 0.711790800095
# Epoch: [ 0] [ 508/2614] time: 7764.1487, d_loss: 1.06703591347, g_loss: 0.75981938839
# Epoch: [ 0] [ 509/2614] time: 7778.6217, d_loss: 1.1753180027, g_loss: 0.941418766975
# Epoch: [ 0] [ 510/2614] time: 7793.4258, d_loss: 1.01667022705, g_loss: 1.02929651737
# Epoch: [ 0] [ 511/2614] time: 7808.2017, d_loss: 1.11089539528, g_loss: 1.01909208298
# Epoch: [ 0] [ 512/2614] time: 7823.3011, d_loss: 1.32546508312, g_loss: 1.20764493942
# Epoch: [ 0] [ 513/2614] time: 7837.9670, d_loss: 1.29944610596, g_loss: 1.03336381912
# Epoch: [ 0] [ 514/2614] time: 7852.9726, d_loss: 1.32350122929, g_loss: 0.783015370369
# Epoch: [ 0] [ 515/2614] time: 7867.8593, d_loss: 1.29558193684, g_loss: 0.672664880753
# Epoch: [ 0] [ 516/2614] time: 7882.9387, d_loss: 1.14495384693, g_loss: 1.02788805962
# Epoch: [ 0] [ 517/2614] time: 7897.6050, d_loss: 1.21775698662, g_loss: 0.89562946558
# Epoch: [ 0] [ 518/2614] time: 7912.9656, d_loss: 1.27696990967, g_loss: 1.25762081146
# Epoch: [ 0] [ 519/2614] time: 7927.8281, d_loss: 1.21151280403, g_loss: 0.601626873016
# Epoch: [ 0] [ 520/2614] time: 7943.0492, d_loss: 1.20782089233, g_loss: 1.02385759354
# Epoch: [ 0] [ 521/2614] time: 7958.0976, d_loss: 1.3226954937, g_loss: 1.37151920795
# Epoch: [ 0] [ 522/2614] time: 7973.3652, d_loss: 1.24614453316, g_loss: 0.548735558987
# Epoch: [ 0] [ 523/2614] time: 7988.7899, d_loss: 1.12913918495, g_loss: 1.09383535385
# Epoch: [ 0] [ 524/2614] time: 8004.8485, d_loss: 1.11210274696, g_loss: 0.78059232235
# Epoch: [ 0] [ 525/2614] time: 8020.2770, d_loss: 1.41093289852, g_loss: 1.41400957108
# Epoch: [ 0] [ 526/2614] time: 8035.5457, d_loss: 1.43498039246, g_loss: 1.22301268578
# Epoch: [ 0] [ 527/2614] time: 8051.1330, d_loss: 1.19375836849, g_loss: 0.642918109894
# Epoch: [ 0] [ 528/2614] time: 8066.6390, d_loss: 1.4519957304, g_loss: 1.71906423569
# Epoch: [ 0] [ 529/2614] time: 8082.2241, d_loss: 1.23442840576, g_loss: 0.544438779354
# Epoch: [ 0] [ 530/2614] time: 8097.7285, d_loss: 1.33613967896, g_loss: 1.44312751293
# Epoch: [ 0] [ 531/2614] time: 8113.4607, d_loss: 1.34101128578, g_loss: 0.936213731766
# Epoch: [ 0] [ 532/2614] time: 8129.5359, d_loss: 1.2755317688, g_loss: 0.773671507835
# Epoch: [ 0] [ 533/2614] time: 8145.3005, d_loss: 1.27566921711, g_loss: 1.22785711288
# Epoch: [ 0] [ 534/2614] time: 8160.9974, d_loss: 1.4716719389, g_loss: 0.381374776363
# Epoch: [ 0] [ 535/2614] time: 8176.8543, d_loss: 1.20137941837, g_loss: 1.67541241646
# Epoch: [ 0] [ 536/2614] time: 8192.8840, d_loss: 1.25553524494, g_loss: 0.641605734825
# Epoch: [ 0] [ 537/2614] time: 8208.7064, d_loss: 1.12481951714, g_loss: 1.13607048988
# Epoch: [ 0] [ 538/2614] time: 8224.6501, d_loss: 1.35436439514, g_loss: 1.13445353508
# Epoch: [ 0] [ 539/2614] time: 8240.6809, d_loss: 1.24804067612, g_loss: 0.771977186203
# Epoch: [ 0] [ 540/2614] time: 8256.7119, d_loss: 1.30475378036, g_loss: 0.98647081852
# Epoch: [ 0] [ 541/2614] time: 8272.9072, d_loss: 1.52257466316, g_loss: 0.385263025761
# Epoch: [ 0] [ 542/2614] time: 8289.0594, d_loss: 1.21460413933, g_loss: 1.0612745285
# Epoch: [ 0] [ 543/2614] time: 8305.3449, d_loss: 1.1497836113, g_loss: 0.802158534527
# Epoch: [ 0] [ 544/2614] time: 8321.5016, d_loss: 1.12448203564, g_loss: 0.902104735374
# Epoch: [ 0] [ 545/2614] time: 8337.7944, d_loss: 1.50295710564, g_loss: 1.26967525482
# Epoch: [ 0] [ 546/2614] time: 8353.9295, d_loss: 1.42443990707, g_loss: 0.465494066477
# Epoch: [ 0] [ 547/2614] time: 8370.7873, d_loss: 1.24357533455, g_loss: 1.23739027977
# Epoch: [ 0] [ 548/2614] time: 8386.9873, d_loss: 1.05967652798, g_loss: 0.833978712559
# Epoch: [ 0] [ 549/2614] time: 8403.2721, d_loss: 1.26595938206, g_loss: 0.891683220863
# Epoch: [ 0] [ 550/2614] time: 8419.4521, d_loss: 1.35555005074, g_loss: 1.13614439964
# Epoch: [ 0] [ 551/2614] time: 8435.7700, d_loss: 1.24930667877, g_loss: 0.741858482361
# ...
# Epoch: [ 1] [2162/2614] time: 101325.6108, d_loss: 1.01472210884, g_loss: 0.912592828274
# Epoch: [ 1] [2163/2614] time: 101361.3085, d_loss: 1.19241714478, g_loss: 1.50602519512
# Epoch: [ 1] [2164/2614] time: 101388.6624, d_loss: 1.12421703339, g_loss: 1.0142352581
# Epoch: [ 1] [2165/2614] time: 101421.6828, d_loss: 1.28664898872, g_loss: 1.17824363708
# Epoch: [ 1] [2166/2614] time: 101452.3703, d_loss: 1.3410410881, g_loss: 1.06572139263
# Epoch: [ 1] [2167/2614] time: 101478.1689, d_loss: 0.962665498257, g_loss: 0.795838534832
# Epoch: [ 1] [2168/2614] time: 101502.1722, d_loss: 0.958377718925, g_loss: 1.53395593166
# Epoch: [ 1] [2169/2614] time: 101528.4038, d_loss: 0.884551167488, g_loss: 1.07332444191
# Epoch: [ 1] [2170/2614] time: 101554.3177, d_loss: 0.935255289078, g_loss: 1.02089500427
# Epoch: [ 1] [2171/2614] time: 101577.6373, d_loss: 1.01026558876, g_loss: 0.890165805817
# Epoch: [ 1] [2172/2614] time: 101602.2797, d_loss: 1.2074226141, g_loss: 0.647751092911
# Epoch: [ 1] [2173/2614] time: 101624.0043, d_loss: 1.4638286829, g_loss: 1.90892636776
# Epoch: [ 1] [2174/2614] time: 101647.7713, d_loss: 1.04047429562, g_loss: 0.719206690788
# Epoch: [ 1] [2175/2614] time: 101671.4224, d_loss: 1.23431503773, g_loss: 1.08349895477
# Epoch: [ 1] [2176/2614] time: 101698.7917, d_loss: 1.45431351662, g_loss: 1.43967461586
# Epoch: [ 1] [2177/2614] time: 101722.7654, d_loss: 0.93102067709, g_loss: 0.987043976784
# Epoch: [ 1] [2178/2614] time: 101750.4860, d_loss: 1.17259180546, g_loss: 1.58580887318
# Epoch: [ 1] [2179/2614] time: 101778.5599, d_loss: 1.23776423931, g_loss: 1.16577315331
# Epoch: [ 1] [2180/2614] time: 101804.7093, d_loss: 1.01382303238, g_loss: 0.786185026169
# Epoch: [ 1] [2181/2614] time: 101830.8162, d_loss: 1.13040280342, g_loss: 2.02944517136
# Epoch: [ 1] [2182/2614] time: 101862.1629, d_loss: 1.07903778553, g_loss: 0.765412390232
# Epoch: [ 1] [2183/2614] time: 101889.6183, d_loss: 1.14028835297, g_loss: 0.522048354149
# Epoch: [ 1] [2184/2614] time: 101914.1795, d_loss: 1.30791401863, g_loss: 1.74594783783
# Epoch: [ 1] [2185/2614] time: 101935.5737, d_loss: 1.02257668972, g_loss: 1.11837089062
# Epoch: [ 1] [2186/2614] time: 101953.3241, d_loss: 1.05852615833, g_loss: 1.02645039558
# Saved model
# Sample saved: True
# Epoch: [ 1] [2187/2614] time: 101973.4291, d_loss: 1.66827487946, g_loss: 2.09995794296
# Epoch: [ 1] [2188/2614] time: 102892.0326, d_loss: 1.35283648968, g_loss: 0.430468946695
# Epoch: [ 1] [2189/2614] time: 102918.6803, d_loss: 0.931733608246, g_loss: 1.6751408577
# Epoch: [ 1] [2190/2614] time: 102932.9982, d_loss: 1.04584789276, g_loss: 0.827993273735
# Epoch: [ 1] [2191/2614] time: 102946.2743, d_loss: 1.0599745512, g_loss: 0.615555167198
# Epoch: [ 1] [2192/2614] time: 130531.2568, d_loss: 1.40529763699, g_loss: 1.99286901951
# Epoch: [ 1] [2193/2614] time: 130559.3832, d_loss: 1.19092953205, g_loss: 1.4972641468
# Epoch: [ 1] [2194/2614] time: 130572.9242, d_loss: 0.969794690609, g_loss: 1.03786766529
# Epoch: [ 1] [2195/2614] time: 131496.2889, d_loss: 0.96663236618, g_loss: 1.470900774
# Epoch: [ 1] [2196/2614] time: 131509.5166, d_loss: 1.02464389801, g_loss: 0.934487819672
# Epoch: [ 1] [2197/2614] time: 131523.3626, d_loss: 1.24645709991, g_loss: 1.17491769791
# Epoch: [ 1] [2198/2614] time: 133506.2214, d_loss: 1.18237400055, g_loss: 0.635651707649
# Epoch: [ 1] [2199/2614] time: 133519.7253, d_loss: 1.11471354961, g_loss: 1.17013192177
# Epoch: [ 1] [2200/2614] time: 133561.1898, d_loss: 1.09868597984, g_loss: 1.56212496758
# Epoch: [ 1] [2201/2614] time: 133576.4725, d_loss: 1.12726330757, g_loss: 0.537480175495
# Epoch: [ 1] [2202/2614] time: 133590.3916, d_loss: 0.959399580956, g_loss: 1.68417918682
# Epoch: [ 1] [2203/2614] time: 133965.8611, d_loss: 1.06372225285, g_loss: 0.656383037567
# Epoch: [ 1] [2204/2614] time: 133992.0383, d_loss: 1.20851814747, g_loss: 1.91178691387
# Epoch: [ 1] [2205/2614] time: 134022.1975, d_loss: 1.15343880653, g_loss: 1.07531440258
# Epoch: [ 1] [2206/2614] time: 134060.7222, d_loss: 1.12363147736, g_loss: 0.578990221024
# Epoch: [ 1] [2207/2614] time: 134085.5635, d_loss: 1.06885933876, g_loss: 1.81853723526
# Epoch: [ 1] [2208/2614] time: 134100.8533, d_loss: 0.955354571342, g_loss: 1.12558054924
# Epoch: [ 1] [2209/2614] time: 134115.2287, d_loss: 0.945517063141, g_loss: 1.04083943367
# Epoch: [ 1] [2210/2614] time: 134877.6143, d_loss: 0.965267598629, g_loss: 1.28091359138
# Epoch: [ 1] [2211/2614] time: 134893.2786, d_loss: 1.22718012333, g_loss: 1.14065539837
# Epoch: [ 1] [2212/2614] time: 134913.2998, d_loss: 1.38737714291, g_loss: 0.448724627495
# Epoch: [ 1] [2213/2614] time: 134927.5965, d_loss: 1.48534762859, g_loss: 1.87057256699
# Epoch: [ 1] [2214/2614] time: 134941.3805, d_loss: 1.14409661293, g_loss: 0.678756654263
# Epoch: [ 1] [2215/2614] time: 134955.1387, d_loss: 0.905252039433, g_loss: 1.0908946991
# Epoch: [ 1] [2216/2614] time: 134969.1405, d_loss: 1.05397605896, g_loss: 0.957620382309
# Epoch: [ 1] [2217/2614] time: 134982.8321, d_loss: 1.00221598148, g_loss: 0.893571019173
# Epoch: [ 1] [2218/2614] time: 134996.1142, d_loss: 0.993838310242, g_loss: 1.11324715614
# Epoch: [ 1] [2219/2614] time: 135009.3252, d_loss: 1.02670717239, g_loss: 1.40257787704
# Epoch: [ 1] [2220/2614] time: 135023.1327, d_loss: 1.09417366982, g_loss: 1.22390413284
# Epoch: [ 1] [2221/2614] time: 135038.6471, d_loss: 1.2993581295, g_loss: 1.12931251526
# Epoch: [ 1] [2222/2614] time: 135053.7073, d_loss: 1.1878041029, g_loss: 1.22267067432
# Epoch: [ 1] [2223/2614] time: 135067.1929, d_loss: 1.13837969303, g_loss: 0.898357689381
# Epoch: [ 1] [2224/2614] time: 135080.9077, d_loss: 1.76282441616, g_loss: 2.02790403366
# Epoch: [ 1] [2225/2614] time: 135094.1414, d_loss: 1.07470357418, g_loss: 0.734252333641
# Epoch: [ 1] [2226/2614] time: 135108.5971, d_loss: 1.05184626579, g_loss: 0.958965301514
# Epoch: [ 1] [2227/2614] time: 135122.4774, d_loss: 1.1724255085, g_loss: 1.03029382229
# Epoch: [ 1] [2228/2614] time: 135135.5730, d_loss: 1.09185099602, g_loss: 0.886802852154
# Epoch: [ 1] [2229/2614] time: 135152.1281, d_loss: 1.03572010994, g_loss: 1.15650177002
# Epoch: [ 1] [2230/2614] time: 135175.2498, d_loss: 1.18849349022, g_loss: 1.35923206806
# Epoch: [ 1] [2231/2614] time: 135200.4873, d_loss: 1.15026974678, g_loss: 0.600170850754
# Epoch: [ 1] [2232/2614] time: 135227.2229, d_loss: 1.36611258984, g_loss: 2.31942629814
# Epoch: [ 1] [2233/2614] time: 135251.0903, d_loss: 1.11366701126, g_loss: 1.21201395988
# Epoch: [ 1] [2234/2614] time: 135274.4566, d_loss: 1.48070430756, g_loss: 1.21890568733
# Epoch: [ 1] [2235/2614] time: 135300.1366, d_loss: 1.91391336918, g_loss: 3.43715000153
# Epoch: [ 1] [2236/2614] time: 135325.7094, d_loss: 1.09848666191, g_loss: 0.72027182579
# Epoch: [ 1] [2237/2614] time: 135349.4038, d_loss: 1.19270181656, g_loss: 0.879441857338
# Epoch: [ 1] [2238/2614] time: 135374.7445, d_loss: 1.16704893112, g_loss: 0.714958906174
# Epoch: [ 1] [2239/2614] time: 135398.0940, d_loss: 1.41997158527, g_loss: 1.95272946358
# Epoch: [ 1] [2240/2614] time: 135433.8598, d_loss: 1.17768168449, g_loss: 0.624444663525
# Epoch: [ 1] [2241/2614] time: 135460.6290, d_loss: 1.19434630871, g_loss: 1.5103482008
# Epoch: [ 1] [2242/2614] time: 135484.1314, d_loss: 1.27263796329, g_loss: 0.660728275776
# Epoch: [ 1] [2243/2614] time: 135510.3807, d_loss: 1.2094810009, g_loss: 1.26714730263
# Epoch: [ 1] [2244/2614] time: 135538.2717, d_loss: 1.13722121716, g_loss: 0.841473340988
# Epoch: [ 1] [2245/2614] time: 135568.1187, d_loss: 1.31568324566, g_loss: 1.07442951202
# Epoch: [ 1] [2246/2614] time: 135593.0349, d_loss: 1.26774418354, g_loss: 0.981226921082
# Epoch: [ 1] [2247/2614] time: 135614.7781, d_loss: 1.57548844814, g_loss: 1.68973708153
# Epoch: [ 1] [2248/2614] time: 135641.4619, d_loss: 1.09621369839, g_loss: 0.815139472485
# Epoch: [ 1] [2249/2614] time: 135664.9270, d_loss: 1.11742186546, g_loss: 0.883209228516
# Epoch: [ 1] [2250/2614] time: 135691.7963, d_loss: 1.28465270996, g_loss: 2.28358697891
# Epoch: [ 1] [2251/2614] time: 135712.8835, d_loss: 1.67659187317, g_loss: 1.75015687943
# Epoch: [ 1] [2252/2614] time: 135734.2153, d_loss: 1.26623523235, g_loss: 0.446027100086
# Epoch: [ 1] [2253/2614] time: 135759.1767, d_loss: 0.963376283646, g_loss: 1.38347172737
# Epoch: [ 1] [2254/2614] time: 135779.8281, d_loss: 1.06225550175, g_loss: 1.30483686924
# Epoch: [ 1] [2255/2614] time: 135797.1909, d_loss: 1.17191743851, g_loss: 1.11654257774
# Epoch: [ 1] [2256/2614] time: 135816.0575, d_loss: 1.21716713905, g_loss: 0.452260881662
# Epoch: [ 1] [2257/2614] time: 135837.5562, d_loss: 1.0227792263, g_loss: 1.40122866631
# Epoch: [ 1] [2258/2614] time: 135856.3148, d_loss: 1.10716772079, g_loss: 0.595312476158
# Epoch: [ 1] [2259/2614] time: 135874.9461, d_loss: 1.02682614326, g_loss: 0.915408849716
# Epoch: [ 1] [2260/2614] time: 135891.2090, d_loss: 1.28765428066, g_loss: 1.50405216217
# Epoch: [ 1] [2261/2614] time: 135909.5409, d_loss: 1.02487182617, g_loss: 0.767925977707
# Epoch: [ 1] [2262/2614] time: 135927.8285, d_loss: 1.50589561462, g_loss: 1.74419665337
# Epoch: [ 1] [2263/2614] time: 135947.3840, d_loss: 1.41066670418, g_loss: 1.40046095848
# Epoch: [ 1] [2264/2614] time: 135969.2648, d_loss: 1.20062494278, g_loss: 0.860371589661
# Epoch: [ 1] [2265/2614] time: 135991.0899, d_loss: 1.14872610569, g_loss: 0.634122610092
# Epoch: [ 1] [2266/2614] time: 136013.7989, d_loss: 1.17892539501, g_loss: 1.32460665703
# Epoch: [ 1] [2267/2614] time: 136035.3646, d_loss: 0.979773759842, g_loss: 0.841101765633
# Epoch: [ 1] [2268/2614] time: 136058.0277, d_loss: 1.00406241417, g_loss: 1.27060639858
# Epoch: [ 1] [2269/2614] time: 136079.8661, d_loss: 0.920997440815, g_loss: 1.15942025185
# Epoch: [ 1] [2270/2614] time: 136102.0100, d_loss: 1.01141810417, g_loss: 0.912799537182
# Epoch: [ 1] [2271/2614] time: 136126.7002, d_loss: 1.12057876587, g_loss: 0.89432322979
# Epoch: [ 1] [2272/2614] time: 136151.3647, d_loss: 1.36576843262, g_loss: 1.06978583336
# Epoch: [ 1] [2273/2614] time: 136173.8031, d_loss: 1.09254062176, g_loss: 1.03041291237
# Epoch: [ 1] [2274/2614] time: 136198.4733, d_loss: 1.72139143944, g_loss: 1.26358938217
# Epoch: [ 1] [2275/2614] time: 136221.3254, d_loss: 1.15111911297, g_loss: 1.07790124416
# Epoch: [ 1] [2276/2614] time: 136243.9827, d_loss: 1.06798160076, g_loss: 0.927389681339
# Epoch: [ 1] [2277/2614] time: 136267.8333, d_loss: 0.988034069538, g_loss: 0.807931065559
# Epoch: [ 1] [2278/2614] time: 136295.8796, d_loss: 1.10375463963, g_loss: 1.37516307831
# Epoch: [ 1] [2279/2614] time: 136318.3195, d_loss: 0.971358776093, g_loss: 0.937077641487
# Epoch: [ 1] [2280/2614] time: 136340.7702, d_loss: 1.82535862923, g_loss: 2.67035961151
# Epoch: [ 1] [2281/2614] time: 136364.8452, d_loss: 1.02071154118, g_loss: 0.730122327805
# Epoch: [ 1] [2282/2614] time: 136388.2077, d_loss: 1.17622566223, g_loss: 0.540464878082
# Epoch: [ 1] [2283/2614] time: 136413.1188, d_loss: 1.57094752789, g_loss: 2.18476366997
# Epoch: [ 1] [2284/2614] time: 136440.4940, d_loss: 1.96588182449, g_loss: 1.88134384155
# Epoch: [ 1] [2285/2614] time: 136462.5116, d_loss: 1.10925936699, g_loss: 0.545208215714
# Epoch: [ 1] [2286/2614] time: 136484.6399, d_loss: 0.991217374802, g_loss: 1.80758082867
# Saved model
# Sample saved: True
# Epoch: [ 1] [2287/2614] time: 136513.0175, d_loss: 1.26182889938, g_loss: 1.23053336143
# Epoch: [ 1] [2288/2614] time: 136535.6505, d_loss: 1.31642436981, g_loss: 0.902740061283
# Epoch: [ 1] [2289/2614] time: 136556.5707, d_loss: 1.04551458359, g_loss: 0.894266486168
# Epoch: [ 1] [2290/2614] time: 136579.2366, d_loss: 1.33172035217, g_loss: 1.57108569145
# Epoch: [ 1] [2291/2614] time: 136601.7555, d_loss: 0.894325911999, g_loss: 1.02044534683
# Epoch: [ 1] [2292/2614] time: 136624.5841, d_loss: 1.18228960037, g_loss: 0.714949250221
# Epoch: [ 1] [2293/2614] time: 136646.7596, d_loss: 1.31386780739, g_loss: 1.46513390541
# Epoch: [ 1] [2294/2614] time: 136670.0033, d_loss: 1.08059442043, g_loss: 0.659669339657
# Epoch: [ 1] [2295/2614] time: 136694.5353, d_loss: 1.04147088528, g_loss: 1.61650562286
# Epoch: [ 1] [2296/2614] time: 136718.8255, d_loss: 1.14468073845, g_loss: 1.29239737988
# Epoch: [ 1] [2297/2614] time: 136742.8424, d_loss: 1.16282200813, g_loss: 1.12088811398
# Epoch: [ 1] [2298/2614] time: 136766.0032, d_loss: 1.24720931053, g_loss: 0.68981552124
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-dabe9506b4f6> in <module>()
#       1 with tf.Session() as sess:
# ----> 2     train(sess, load_dir='/Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/checkpoint', save_dir='checkpoint')
#
# <ipython-input-12-34b56ce86865> in train(sess, load_dir, save_frequency, sample_frequency, sample_dir, save_dir, max_to_keep, model_name, n_epochs, n_generator_update)
#      58                         feed_dict={z: batch_z, is_training: True})
#      59
# ---> 60                 errD_fake = d_loss_fake.eval({z: batch_z, is_training: False})
#      61                 errD_real = d_loss_real.eval({images: batch_images, is_training: False})
#      62                 errG = g_loss.eval({z: batch_z, is_training: False})
#
# /Library/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in eval(self, feed_dict, session)
#     708
#     709     """
# --> 710     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     711
#     712
#
# /Library/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in _eval_using_default_session(tensors, feed_dict, graph, session)
#    5178                        "the tensor's graph is different from the session's "
#    5179                        "graph.")
# -> 5180   return session.run(tensors, feed_dict)
#    5181
#    5182
#
# /Library/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Library/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# /Library/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /Library/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# /Library/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# /Library/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
batch_z = np.random.uniform(-1, 1, [BATCH_SIZE, Z_DIM]).astype(np.float32)

# %%
load_dir='/Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/checkpoint'
with tf.Session() as sess:
    load(sess, load_dir)
    samples = sess.run(G, feed_dict={z: batch_z, is_training: False})
    res = save_images(samples, [MERGE_X, MERGE_Y],
                                os.path.join('/Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/', 'test_sample.png'))
# Out:
# INFO:tensorflow:Restoring parameters from /Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/checkpoint/dcgan.model

# %%
path = os.path.join('/Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/', 'test_sample.png')
im = cv2.imread(path)
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(10,10))
plt.imshow(im)

# %% [markdown]
# If you generated something that looks like a face - it's cool! Add 2 points to your mark.

# %% [markdown]
# ## Face interpolation (1 point)

# %% [markdown]
# Let's interpolate between faces: generate two vectors $z_1$ and $z_2$ and get a batch of vectors of the form $\alpha\cdot z_1 + (1- \alpha)\cdot  z_2, \alpha \in [0,1].$ Generate faces on them and look at results. The generator displays pictures in the range from -1 to 1, so use the inverse transform function from the file utils.py.

# %%
batch_z_1 = np.random.uniform(-1, 1, [1, Z_DIM]).astype(np.float32)
batch_z_2 = np.random.uniform(-1, 1, [1, Z_DIM]).astype(np.float32)

# %%
batch_z = []
for i in range(63):
    alpha = i/63.0
    batch_z.append(batch_z_1[0]*alpha + (1-alpha)*batch_z_2[0])
batch_z.append(batch_z_1[0])

# %%
load_dir='/Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/checkpoint'
with tf.Session() as sess:
    load(sess, load_dir)
    samples = sess.run(G, feed_dict={z: batch_z, is_training: False})
    res = save_images(samples, [MERGE_X, MERGE_Y],
                                os.path.join('/Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/', 'test_sample.png'))
# Out:
# INFO:tensorflow:Restoring parameters from /Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/checkpoint/dcgan.model

# %%
path = os.path.join('/Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/', 'test_sample.png')
im = cv2.imread(path)
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(10,10))
plt.imshow(im)

# %% [markdown]
# ## Adding a smile (1 point + 1 point for good results)

# %% [markdown]
# Let's make face smiling. Find several vectors z, such that the generator generates smiling faces and not. Five vectors in every group should be enough (but the more, the better).

# %% [markdown]
# Calculate "smile vector" as mean of vectors z with generated smile on it minus mean of vectors z with generated not smile on it.

# %% [markdown]
# Look at the result of applying the smile vector: compare the results of generation before and after the addition of the smile vector.

# %%
z1 = batch_z_1 #- smiling
z2 = batch_z_2

# %%
z3=batch_z_1#- smiling
z4 = batch_z_2

# %%
z5=batch_z_1#- smiling
z6 = batch_z_2

# %%
z7=batch_z_1#- smiling
z8 = batch_z_2

# %%
z10=batch_z_1

# %%
z9=batch_z_2#- smiling

# %%
smile_vector = (z1+z3+z5+z7+z9)/5.0-(z2+z4+z6+z8+z10)/5.0

# %%
batch_z_1 = np.random.uniform(-1, 1, [1, Z_DIM]).astype(np.float32)
batch_z_2 = batch_z_1+smile_vector#np.random.uniform(-1, 1, [1, Z_DIM]).astype(np.float32)

# %%
batch_z = []
for i in range(63):
    alpha = i/63.0
    batch_z.append(batch_z_1[0]*alpha + (1-alpha)*batch_z_2[0])
batch_z.append(batch_z_1[0])

# %%
load_dir='/Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/checkpoint'
with tf.Session() as sess:
    load(sess, load_dir)
    samples = sess.run(G, feed_dict={z: batch_z, is_training: False})
    res = save_images(samples, [MERGE_X, MERGE_Y],
                                os.path.join('/Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/', 'test_sample.png'))
# Out:
# INFO:tensorflow:Restoring parameters from /Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/checkpoint/dcgan.model

# %%
path = os.path.join('/Users/nikitakaraev/Desktop/Computer_visionHES-coursera/gan-task/', 'test_sample.png')
im = cv2.imread(path)
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(10,10))
plt.imshow(im)
#first faces were generated with addition of the smile vector

# %% [markdown]
# If faces looks really cool, add bonus 1 point to your score.
